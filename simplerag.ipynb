# %% [markdown]
# # NEW APPROACH\

# %%
# Importing required libraries
from langchain.text_splitter import RecursiveCharacterTextSplitter
from PyPDF2 import PdfReader
import os

# Specify the folder containing PDF files
pdf_folder = "Data/"  # Replace with the path to your folder

# Initialize a list to hold all chunks
all_chunks = []

# Define the chunk size and overlap
chunk_size = 500  # Number of characters in each chunk
chunk_overlap = 50  # Overlapping characters between chunks

# Initialize text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap
)

# Loop through all PDFs in the folder
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        print(f"Processing file: {filename}")

        # Read the PDF
        pdf_reader = PdfReader(pdf_path)

        # Extract text from all pages
        pdf_text = ""
        for page in pdf_reader.pages:
            pdf_text += page.extract_text()

        # Split the text into chunks
        chunks = text_splitter.split_text(pdf_text)
        print(f"Extracted {len(chunks)} chunks from {filename}")

        # Append chunks to the list
        all_chunks.extend(chunks)

print(f"Total chunks extracted: {len(all_chunks)}")
# Out:
# Processing file: Attendance and Punctuality_final.pdf
# Extracted 16 chunks from Attendance and Punctuality_final.pdf
# Processing file: Compensatory Off Policy_final.pdf
# Extracted 6 chunks from Compensatory Off Policy_final.pdf
# Processing file: Confirmation Policy-new.pdf
# Extracted 6 chunks from Confirmation Policy-new.pdf
# Processing file: EnFuse - Code of Conduct_July24 CS (1)_new.pdf
# Extracted 49 chunks from EnFuse - Code of Conduct_July24 CS (1)_new.pdf
# Processing file: Leave Policy_Updated_new.pdf
# Extracted 18 chunks from Leave Policy_Updated_new.pdf
# Total chunks extracted: 95

# %%
print(all_chunks)
# Out:
# ['1. Policy Brief   \nTimely and regular attendance is an expectation of performance for all EnFuse employees. \nTo ensure adequate staffing, positive employee morale, and to meet expected productivity \nstandards throughout the organization, employees will be held accountable for adhering to \ntheir work schedule. If an employee is unable to meet this expectation, he/she must obtain \napproval from their Manager in advance of any requested schedule changes. This approval', 'includes requests to use appropriate accruals and late arrivals t o or early departures from \nwork. Departments had the discretion to evaluate extraordinary circumstances of a tardy, \nabsence, or failure to check -in or check -out and determine whether or not to count the \nincident as an occurrence. The HR team is available t o advise Managers regarding the \nevaluation of extenuating circumstances.       \n 2. Procedures   \n2.1.   Absent', '2. Procedures   \n2.1.   Absent   \nAn employee is deemed absent when he/she is unavailable for work as assigned/scheduled \nand such time -off was not scheduled/approved in advance as required by the department \nnotification procedure.   \n2.2.   Tardy   \nAn employee is deemed to be tardy when he/she:   \n▪ Fails to report for work at the assigned/scheduled work time. Managers may replace the \ntardy employee for the full shift in these instances.', '▪ Leaves work before the end of assigned/scheduled work time without prior supervisory \napproval   \n▪ Takes an extended meal or break period without approval   \n▪ Arrives to work past his/her scheduled start time. They may be replaced for the full shift at \nthe discretion of his/her Manager/Supervisor.   \n2.3.   Check In/Out on Zoho   \nEmployees are required to follow established guidelines for recording their actual hours', 'worked. A missed check in/out is a violation of this policy and includes:   \n▪ Failure to check -in/out on their designated time check at the beginning and/or end of \ntheir assigned shift   \n▪ Failure to check -in/out on their designated time check for the meal break   \n▪ Failure to accurately and timely report time worked   \n▪ Checking in/out early (or late) of the assigned shift without prior approval   \n2.4.   Departmental Notification Procedure', '2.4.   Departmental Notification Procedure   \nEmployees are expected to follow departmental notification procedures if they will be late \nfor work, will not be at work, or are requesting planned time away from work. Employees \nmust request in advance to their Manager and in accordance with the departmen tal \nprocedure if they wish to arrive early or leave early from an assigned shift.   \nAt the time of notification/call, the employee must notify their Managers/Supervisors when an', 'absence is due to a documented/approved leave of absence to ensure appropriate \ntracking of leave utilization and absenteeism.   \nAn employee who fails to call in and report to work as scheduled for five consecutively \nscheduled workdays will be viewed as having abandoned their position and shall be treated \nas an absconding case following respective processes. The Manager should consu lt with \nHuman Resources if this situation occurs.', "Human Resources if this situation occurs.     \n  \nIncidents of not following the departmental notification procedures, including   \nNo-Call/No -Show, will be addressed in accordance with the Discipline Process Protocol.   \n2.5.   Discipline Process Protocol   \nManagers/Supervisors should monitor their employees' attendance regularly and address \nunsatisfactory attendance in a timely and consistent manner. If Managers/Supervisors notice", 'a pattern of unscheduled usage of accrued time off work, they should discuss t his concern \nwith the employee.   \nWhen an employee has been previously counseled under the Discipline/Code of Conduct \nPolicy and/or the Information Security Awareness Policy, the totality of the circumstances will \nbe assessed when determi ...

# %%
# Importing required libraries
from sentence_transformers import SentenceTransformer
import faiss
import pickle

# Load the pre-trained embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings for each chunk
print("Generating embeddings for chunks...")
chunk_embeddings = embedding_model.encode(all_chunks, show_progress_bar=True)

# Convert embeddings to a format compatible with FAISS
chunk_embeddings = chunk_embeddings.astype("float32")

# Create a FAISS index and add the embeddings
print("Storing embeddings in FAISS index...")
index = faiss.IndexFlatL2(chunk_embeddings.shape[1])  # L2 distance
index.add(chunk_embeddings)

# Save the FAISS index and metadata for later use
faiss_index_path = "embeddings/hr_policy_faiss.index"
metadata_path = "embeddings/hr_policy_faiss_metadata.pkl"

# Save the FAISS index
faiss.write_index(index, faiss_index_path)

# Save the metadata (chunks) for mapping back to the original content
with open(metadata_path, 'wb') as metadata_file:
    pickle.dump(all_chunks, metadata_file)

print(f"FAISS index saved at {faiss_index_path}")
print(f"Metadata saved at {metadata_path}")
# Out:
# Generating embeddings for chunks...
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Storing embeddings in FAISS index...
# FAISS index saved at embeddings/hr_policy_faiss.index
# Metadata saved at embeddings/hr_policy_faiss_metadata.pkl

# %%
# Import required libraries
import faiss
from sentence_transformers import SentenceTransformer
import pickle

# Paths to FAISS index and metadata
faiss_index_path = "embeddings/hr_policy_faiss.index"
metadata_path = "embeddings/hr_policy_faiss_metadata.pkl"

# Load the FAISS index
print("Loading FAISS index...")
index = faiss.read_index(faiss_index_path)

# Load metadata (original chunks)
print("Loading metadata...")
with open(metadata_path, 'rb') as metadata_file:
    chunks = pickle.load(metadata_file)

# Load the same embedding model used for creating the index
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Define the retrieval function
def retrieve_relevant_chunks(query, top_k=5):
    # Generate embedding for the query
    query_embedding = embedding_model.encode([query]).astype("float32")

    # Search for top_k most similar chunks
    distances, indices = index.search(query_embedding, top_k)

    # Map indices to chunks
    results = []
    for idx, dist in zip(indices[0], distances[0]):
        if idx != -1:  # Valid index
            results.append((chunks[idx], dist))

    return results

# Example query
query = "What is the probation period for new hires?"
top_k = 5  # Number of relevant chunks to retrieve

# Retrieve results
retrieved_chunks = retrieve_relevant_chunks(query, top_k=top_k)

# Display results
print(f"\nQuery: {query}")
print("\nTop Relevant Chunks:")
for i, (chunk, distance) in enumerate(retrieved_chunks, 1):
    print(f"\nChunk {i}:")
    print(f"Content: {chunk}")
    print(f"Distance: {distance:.4f}")
# Out:
# Loading FAISS index...
# Loading metadata...
#
# Query: What is the probation period for new hires?
#
# Top Relevant Chunks:
#
# Chunk 1:
# Content: 2.5.2.  New Hire Probation Period
# An employee within his/her probation period who has two occurrences will receive a Written
# Warning. If the employee has greater than two occurrences within the probation period,
# employment may be terminated; should the probation period be extended, this ru le still
# applies.
# 2.5.3.  Holidays
# If an employee calls out of work the day before, the day of, or the day after a holiday, the
# Distance: 0.8029
#
# Chunk 2:
# Content: 1.4.  Process
# The standard probation duration lasts three months from the date of joining.
# The confirmation process initiates ten days before the actual confirmation due date.
# ▪ The Manager should maintain employee assessment / feedback
# ▪ In case the employee clears the probation successfully, the Manager can share the
# feedback with HR as a response to the probation alert email
# ▪ HR then confirms the employee in the system and shares the confirmation letter
# Distance: 0.8519
#
# Chunk 3:
# Content: Confirmation Policy
#
# Policy Docume nt
#   1.  Confirmation Policy
# 1.1.  Introduction
# All the new joiners undergo the Probation period. The probationary period is the duration
# provided to the new hires to get oriented with the organization, work, and culture. Also, the
# probation confirmation process helps analyze the new hire's performance during the
# probation period, analyze their qualities, identify the gap, and conclude whether the
# Distance: 0.8998
#
# Chunk 4:
# Content: 2 Instance   Step 3: Final written warning/show cause
#    3 Instance   Step 4: Termination
#
# Note:  The total number of days an employee is unavailable for work as scheduled and the
# total number of instances are considered when applying discipline. For example, at Step 1
# the maximum number of days the employee is allowed to be unavailable for work before
# receiving a Verbal Coaching is 2, regardless of the number of occurrences.
#  2.5.2.  New Hire Probation Period
# Distance: 0.9232
#
# Chunk 5:
# Content: employee should be confirmed in the role or if the employee requires any training or is a
# misfit.
# 1.2.  Scope
# This policy applies to all new hire employees in the organization. This policy applies to full -time
# permanent employees. This policy does not apply to consultants or contractual employees.
# 1.3.  Objective
# To define a detailed procedure for reviewing the probation period and thereafter
# confirmation of employment in the organization.
# 1.4.  Process
# Distance: 1.0199

# %%
import os

# Import required libraries
from langchain.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# Use a pre-trained T5 model from Hugging Face for question answering
# You can replace 't5-base' with any other suitable model
hf_model = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",  # T5 model for text-to-text tasks, you can use any other model
    task="text2text-generation"
)

# Set up the prompt template for your HR policy Q&A
prompt_template = """
You are an AI assistant trained to answer questions about HR policies.
Given the following context and user query, provide a short and accurate answer.

Context:
{context}

Query:
{query}

Answer:
"""

# Initialize the prompt template
prompt = PromptTemplate(
    input_variables=["context", "query"],
    template=prompt_template
)

# Create a chain using the Hugging Face model
llm_chain = LLMChain(llm=hf_model, prompt=prompt)

# Example usage
query = "What is the probation period for new hires?"

# Run the chain with context and query
# response = llm_chain.run(context=context, query=query)
# print("\nResponse from the chain:")
# print(response)

# %%
response = llm_chain.run(context=retrieved_chunks, query=query)

# %%
print(response)
# Out:
# You are an AI assistant trained to answer questions about HR policies.
# Given the following context and user query, provide a short and accurate answer.
#
# Context:
# [('2.5.2.  New Hire Probation Period   \nAn employee within his/her probation period who has two occurrences will receive a Written \nWarning. If the employee has greater than two occurrences within the probation period, \nemployment may be terminated; should the probation period be extended, this ru le still \napplies.   \n2.5.3.  Holidays   \nIf an employee calls out of work the day before, the day of, or the day after a holiday, the', np.float32(0.8029299)), ('1.4.  Process  \nThe standard probation duration lasts three months from the date of joining.  \nThe confirmation process initiates ten days before the actual confirmation due date.  \n▪ The Manager should maintain employee assessment / feedback  \n▪ In case the employee clears the probation successfully, the Manager can share the \nfeedback with HR as a response to the probation alert email  \n▪ HR then confirms the employee in the system and shares the confirmation letter', np.float32(0.8519484)), ("Confirmation Policy  \n \nPolicy Docume nt  \n  1.  Confirmation Policy  \n1.1.  Introduction  \nAll the new joiners undergo the Probation period. The probationary period is the duration \nprovided to the new hires to get oriented with the organization, work, and culture. Also, the \nprobation confirmation process helps analyze the new hire's performance during the \nprobation period, analyze their qualities, identify the gap, and conclude whether the", np.float32(0.89984405)), ('2 Instance   Step 3: Final written warning/show cause   \n   3 Instance   Step 4: Termination   \n   \nNote:  The total number of days an employee is unavailable for work as scheduled and the \ntotal number of instances are considered when applying discipline. For example, at Step 1 \nthe maximum number of days the employee is allowed to be unavailable for work before  \nreceiving a Verbal Coaching is 2, regardless of the number of occurrences.     \n 2.5.2.  New Hire Probation Period', np.float32(0.92318285)), ('employee should be confirmed in the role or if the employee requires any training or is a \nmisfit.  \n1.2.  Scope  \nThis policy applies to all new hire employees in the organization. This policy applies to full -time \npermanent employees. This policy does not apply to consultants or contractual employees.  \n1.3.  Objective  \nTo define a detailed procedure for reviewing the probation period and thereafter \nconfirmation of employment in the organization.  \n1.4.  Process', np.float32(1.0199394))]
#
# Query:
# What is the probation period for new hires?
#
# Answer:
# The standard probation duration lasts three months from the date of joining.

# %%
# Read index files

import pickle

file_path = r'D:\RAG\embeddings\hr_policy_faiss_metadata.pkl'

with open(file_path, 'rb') as file:
    metadata = pickle.load(file)

print(metadata)
# Out:
# ['1. Policy Brief   \nTimely and regular attendance is an expectation of performance for all EnFuse employees. \nTo ensure adequate staffing, positive employee morale, and to meet expected productivity \nstandards throughout the organization, employees will be held accountable for adhering to', 'their work schedule. If an employee is unable to meet this expectation, he/she must obtain \napproval from their Manager in advance of any requested schedule changes. This approval \nincludes requests to use appropriate accruals and late arrivals t o or early departures from', 'work. Departments had the discretion to evaluate extraordinary circumstances of a tardy, \nabsence, or failure to check -in or check -out and determine whether or not to count the \nincident as an occurrence. The HR team is available t o advise Managers regarding the', 'evaluation of extenuating circumstances.       \n 2. Procedures   \n2.1.   Absent   \nAn employee is deemed absent when he/she is unavailable for work as assigned/scheduled \nand such time -off was not scheduled/approved in advance as required by the department \nnotification procedure.', '2.2.   Tardy   \nAn employee is deemed to be tardy when he/she:   \n▪ Fails to report for work at the assigned/scheduled work time. Managers may replace the \ntardy employee for the full shift in these instances.', '▪ Leaves work before the end of assigned/scheduled work time without prior supervisory \napproval   \n▪ Takes an extended meal or break period without approval   \n▪ Arrives to work past his/her scheduled start time. They may be replaced for the full shift at', 'the discretion of his/her Manager/Supervisor.   \n2.3.   Check In/Out on Zoho   \nEmployees are required to follow established guidelines for recording their actual hours \nworked. A missed check in/out is a violation of this policy and includes:', '▪ Failure to check -in/out on their designated time check at the beginning and/or end of \ntheir assigned shift   \n▪ Failure to check -in/out on their designated time check for the meal break   \n▪ Failure to accurately and timely report time worked', '▪ Checking in/out early (or late) of the assigned shift without prior approval   \n2.4.   Departmental Notification Procedure   \nEmployees are expected to follow departmental notification procedures if they will be late', 'for work, will not be at work, or are requesting planned time away from work. Employees \nmust request in advance to their Manager and in accordance with the departmen tal \nprocedure if they wish to arrive early or leave early from an assigned shift.', 'At the time of notification/call, the employee must notify their Managers/Supervisors when an \nabsence is due to a documented/approved leave of absence to ensure appropriate \ntracking of leave utilization and absenteeism.', 'An employee who fails to call in and report to work as scheduled for five consecutively \nscheduled workdays will be viewed as having abandoned their position and shall be treated \nas an absconding case following respective processes. The Manager should consu lt with', 'Human Resources if this situation occurs.     \n  \nIncidents of not following the departmental notification procedures, including   \nNo-Call/No -Show, will be addressed in accordance with the Discipline Process Protocol.   \n2.5.   Discipline Process Protocol', "Managers/Supervisors should monitor their employees' attendance regularly and address \nunsatisfactory attendance in a timely and consistent manner. If Managers/Supervisors notice \na pattern of unscheduled usage of accrued time off work, they should discuss t his concern \nwith the employee.", 'When an employee has been previously counseled under the Discipline/Code of Conduct \nPolicy and/or the Information Security Awareness Policy, the totality of the circumstances will \nbe assessed when determining further action. For situations involving suspen sion or', 'termination of employment, the Managers/Supervisors should consult  ...

# %%
metadata
# Out:
# ['1. Policy Brief   \nTimely and regular attendance is an expectation of performance for all EnFuse employees. \nTo ensure adequate staffing, positive employee morale, and to meet expected productivity \nstandards throughout the organization, employees will be held accountable for adhering to',
#  'their work schedule. If an employee is unable to meet this expectation, he/she must obtain \napproval from their Manager in advance of any requested schedule changes. This approval \nincludes requests to use appropriate accruals and late arrivals t o or early departures from',
#  'work. Departments had the discretion to evaluate extraordinary circumstances of a tardy, \nabsence, or failure to check -in or check -out and determine whether or not to count the \nincident as an occurrence. The HR team is available t o advise Managers regarding the',
#  'evaluation of extenuating circumstances.       \n 2. Procedures   \n2.1.   Absent   \nAn employee is deemed absent when he/she is unavailable for work as assigned/scheduled \nand such time -off was not scheduled/approved in advance as required by the department \nnotification procedure.',
#  '2.2.   Tardy   \nAn employee is deemed to be tardy when he/she:   \n▪ Fails to report for work at the assigned/scheduled work time. Managers may replace the \ntardy employee for the full shift in these instances.',
#  '▪ Leaves work before the end of assigned/scheduled work time without prior supervisory \napproval   \n▪ Takes an extended meal or break period without approval   \n▪ Arrives to work past his/her scheduled start time. They may be replaced for the full shift at',
#  'the discretion of his/her Manager/Supervisor.   \n2.3.   Check In/Out on Zoho   \nEmployees are required to follow established guidelines for recording their actual hours \nworked. A missed check in/out is a violation of this policy and includes:',
#  '▪ Failure to check -in/out on their designated time check at the beginning and/or end of \ntheir assigned shift   \n▪ Failure to check -in/out on their designated time check for the meal break   \n▪ Failure to accurately and timely report time worked',
#  '▪ Checking in/out early (or late) of the assigned shift without prior approval   \n2.4.   Departmental Notification Procedure   \nEmployees are expected to follow departmental notification procedures if they will be late',
#  'for work, will not be at work, or are requesting planned time away from work. Employees \nmust request in advance to their Manager and in accordance with the departmen tal \nprocedure if they wish to arrive early or leave early from an assigned shift.',
#  'At the time of notification/call, the employee must notify their Managers/Supervisors when an \nabsence is due to a documented/approved leave of absence to ensure appropriate \ntracking of leave utilization and absenteeism.',
#  'An employee who fails to call in and report to work as scheduled for five consecutively \nscheduled workdays will be viewed as having abandoned their position and shall be treated \nas an absconding case following respective processes. The Manager should consu lt with',
#  'Human Resources if this situation occurs.     \n  \nIncidents of not following the departmental notification procedures, including   \nNo-Call/No -Show, will be addressed in accordance with the Discipline Process Protocol.   \n2.5.   Discipline Process Protocol',
#  "Managers/Supervisors should monitor their employees' attendance regularly and address \nunsatisfactory attendance in a timely and consistent manner. If Managers/Supervisors notice \na pattern of unscheduled usage of accrued time off work, they should discuss t his concern \nwith the employee.",
#  'When an employee has been previously counseled under the Discipline/Code of Conduct \nPolicy and/or the Information Security Awareness Policy, the totality of the circumstances will \nbe assessed when determining further action. For situations involving suspen sion or',
#  'termination of employment, the Managers/Supervisors should consult with Human Resources \nbefore implementing disciplinary action.   \nTimely and regular attendance is a performance expectation for all EnFuse employees.',
#  'Consequently, those employees who have exhibited unsatisfactory attendance, which \nresulted in disciplinary action (written or final) during the year, may have the behavior  \ndocumented in their annual evaluation.   \n2.5.1.  Instances',
#  'An instance is documented as an absence, tardy, or missed time check -in/out. While an \nabsence refers to a single failure to be at work, an instance may cover consecutive absent \ndays when an employee is out for the same reason.',
#  'The following grid is designed to provide guidelines when addressing the total number of \ninstances:    \n   Instances/Days    Discipline Step/Action   \nAbsence/Tardies/Missed  \nCheck -In/Out   2 Instances   Step 1: Verbal warning   \n   4 Instances   Step 2: Written warning',
#  '6 Instances   Step 3: Final written warning/show cause   \n   Beyond 6 Instances   Step 4: Termination   \n   3 days   Step 1: Verbal warning   \nTotal # of Days Absent   5 days   Step 2: Written warning & absconding \ntrigger   \nConsecutive or Non -',
#  'Consecutive   6 days   Step 3: Final written warning/show cause     \n Does Not Apply to Tardy   Beyond 6 days   Step 4: Termination   \n  \nConfidential – Internal Use Only    Page 3 of 6  \nDay of No Call/No Show   1 Instance   Step 2: Written warning',
#  '2 Instance   Step 3: Final written warning/show cause   \n   3 Instance   Step 4: Termination   \n   \nNote:  The total number of days an employee is unavailable for work as scheduled and the \ntotal number of instances are considered when applying discipline. For example, at Step 1',
#  'the maximum number of days the employee is allowed to be unavailable for work before  \nreceiving a Verbal Coaching is 2, regardless of the number of occurrences.     \n 2.5.2.  New Hire Probation Period   \nAn employee within his/her probation period who has two occurrences will receive a Written',
#  'Warning. If the employee has greater than two occurrences within the probation period, \nemployment may be terminated; should the probation period be extended, this ru le still \napplies.   \n2.5.3.  Holidays',
#  '2.5.3.  Holidays   \nIf an employee calls out of work the day before, the day of, or the day after a holiday, the \nmanager will review the circumstances of the absence. Based on this review, the manager \nhas the discretion to determine whether to count the incident as a regular occurrence or go',
#  'directly to issuing a Written Warning for the holiday -related call out. If an employee is already \non discipline, they can progress to the next level.   \n2.6.   Departmental Policies – Approval Process   \nEnFuse Senior Managers may develop a departmental attendance/punctuality policy that',
#  'meets the unique operational needs of the department. If the leadership determines that a \ndepartmental policy is needed, the department will follow its Senior Manager’s ap proval \nprocess to establish the policy, which requires final approval from the leadership.',
#  "Compensatory Off Policy  \n \n1.  Compensatory Off Policy  \n \n1.1.  Introduction  \nThe Compensatory Off Policy document aims to define EnFuse's approach to the concept of  \nCompensatory policy. This document will act as a guideline, and it is expected that all the \nEnFusians abide by the same.",
#  '1.2.  Definition of Compensatory Off  \nAlso known as Comp Off, Compensatory Off is an optional way of providing leave to \nemployees who work on a holiday or a week off. The Compensatory Off policy provides \nemployees with leaves to be compensated by a holiday or a week off work. Any such',
#  'approved  Holiday / Week off working would be marked as a compensatory off in the system. \nIt can be availed during the eligibility period (provided all the eligibility / validity criteria are \nqualifying).  \n1.3.  Eligibility for Applying for Compensatory Off',
#  'The Employees can only apply for Compensatory Off if they fulfill the following two criteria:  \n▪ The Employee should have worked for One Full Day - On account of a project \nrequirement pre -approved by the respective Manager  \n▪ The Employee should be a Full -time resource',
#  "1.4.  Compensatory Off Process Flow  \nFollowing process allows the employees to add a request for a compensatory off:  \nAdd Compensatory Request.  \n▪ Login to Zoho People Account  \n▪ Go to 'Leave Tracker' and click on 'Compensatory Request'  \n▪ Click on '+Add Request'",
#  "– Fill in all the following details:  \n– a. Employee Name  \n– b. Worked Date  \n– c. Add Description in the box (write specifically about project you worked on)  \n▪ Click on 'Submit'  \n      Once the request is submitted, respective managers will give approval to the same.",
#  "After the request is approved, it reflects in the Compensatory Off list, where you can review the \ncount of compensatory offs.   \n▪ Go to 'Leave Tracker' and click on 'List View'  \nThe List View will appear, and one can see the approved and pending Compensatory offs.  \nAvailing Compensatory Off:",
#  "▪ Click on 'Compensatory Off' in List View  \n▪ Add the details asked:  \n– Date  \n– Reason for leave  \n– And click on 'Submit'  \n1.5.  Validity of Compensatory Off  \nAny approved Compensatory Off is valid for 365 days from the date of approval. Manager to",
#  'approve the Comp Off within a week of the date of week off working / Holiday working.  \n1.6.  Exceptions Management  \nAny exceptions to the Compensatory Off policy to be approved HR L ead.',
#  'Confirmation Policy  \n \nPolicy Docume nt  \n  1.  Confirmation Policy  \n1.1.  Introduction  \nAll the new joiners undergo the Probation period. The probationary period is the duration \nprovided to the new hires to get oriented with the organization, work, and culture. Also, the',
#  "probation confirmation process helps analyze the new hire's performance during the \nprobation period, analyze their qualities, identify the gap, and conclude whether the \nemployee should be confirmed in the role or if the employee requires any training or is a \nmisfit.  \n1.2.  Scope",
#  '1.2.  Scope  \nThis policy applies to all new hire employees in the organization. This policy applies to full -time \npermanent employees. This policy does not apply to consultants or contractual employees.  \n1.3.  Objective',
#  '1.3.  Objective  \nTo define a detailed procedure for reviewing the probation period and thereafter \nconfirmation of employment in the organization.  \n1.4.  Process  \nThe standard probation duration lasts three months from the date of joining.',
#  'The confirmation process initiates ten days before the actual confirmation due date.  \n▪ The Manager should maintain employee assessment / feedback  \n▪ In case the employee clears the probation successfully, the Manager can share the \nfeedback with HR as a response to the probation alert email',
#  '▪ HR then confirms the employee in the system and shares the confirmation letter  \n▪ In case the employee requires more time to clear the probation successfully, the \nprobation period gets extended, and the employee undergoes a Performance',
#  'Improvement Plan (PIP) for a month. Manager to notify HR of such extensions and HR to \nshare the PIP te mplate form to be filled by the Manager. Employee to be apprised jointly \nalong with HR and Manager. The employee gets confirmed post full filling the',
#  'expectations from the PIP form. The employee gets terminated if the expectations from \nthe PIP form are not  met.  \n1.5.  Leave Management  \nThe employee will not be entitled to paid leaves during the probation period. Leaves shall be',
#  'credited to leave balance post successful completion of probation. The employee should \nconsult the Reporting manager for required emergency leaves.  \n1.6.  Exception Management  \nAny exceptions to be above policy shall be approved by the Leadership team, and the',
#  'same shall be liaised by the Human Resources team.',
#  'Code of Conduct  \n \nPolicy Document  \n1. Message from the Co -Founder & Director  \n \nOur commitment to ethical behavior and the solid ethical foundations are one of the most \nessential components of EnFuse Solutions Ltd. operation. We are committed to doing',
#  'business the right way, based on a culture of ethics and compliance.  \nIn the long term, we can successfully face the challenges of a competitive market \nenvironment by accepting the imperatives of moral responsibility, both as individuals and as',
#  'a company. In performing the job duties, the employees should always act lawfully , ethically \nand in the best interests of the EnFuse Solutions Ltd.   \nThank you for upholding our values and helping us do things right. It does not only mean that',
#  'we provide well made, fairly priced and of exceptional quality products and services, but it \nalso means that ethics and integrity is always born in mind. We sourc e material only from \nsuppliers who have impeccable human rights and compliance records, and we ensure that',
#  'our supply chain is of high integrity, and we monitor our entire operation for compliance with \nour Code.  \n  \nKamran Shaikh and Imran Ansari  \nCo-Founder & Director      \n  2.  Introduction  \n \nThis Code of Ethics and Business Conduct  of EnFuse Solutions Ltd. (EnFuse, The Company)',
#  'serves as our ethical commitment and as a guide to proper business conduct for all of our \nstakeholders. We, at EnFuse Solutions Ltd. are committed to doing business legally, ethically \nand in a transparent manner.',
#  'This document applies to all staff who work for EnFuse (including officers, directors, managers, \nteam leaders, employees, temporary, agency, interim, sub -contractor or consultant staff), and \nalso includes other organizations who do business with us.',
#  'EnFuse expects its staff to be impartial and honest in all affairs relating to their job. All staff \nbear a responsibility in general, to be of good faith and do nothing to destroy the trust \nnecessary for employment.',
#  'The success of our business is based on the trust we earn from our employees, customers, and \nshareholders. We gain credibility by adhering to our commitment to fairness and reaching \nour goals solely through ethical conduct. All staff are expected to adhere  to this Code in their',
#  'professional, as well as personal conduct, treat everyone with respect, honesty, and fairness.  \nEnFuse is open to any questions at any time and will not allow punishment or retaliation \nagainst anyone for reporting a misconduct in good faith.',
#  'Managers and leaders have higher responsibility for demonstrating, also through their actions, \nthe importance of this Code. Managers and leaders are responsible for promptly addressing \nevery raised ethical question or concern. Employees must cooperate in i nvestigations of',
#  'potential or alleged misconduct.   \nNon-compliance to this Code is considered as misconduct that could warrant disciplinary \naction, including termination of employment or other contract in deserving cases.',
#  'We are committed to making efforts to apply our values and norms also throughout the entire \nvalue chain of our own suppliers, sub -contractors, service providers and business partners.    \n  3. Ethical Principles of EnFuse',
#  'At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set \nof core values that form the foundation of our business conduct. These principles reflect who \nwe are as an organization and shape our interactions with clients, co lleagues, and the \nbroader community.',
#  '1. Honesty:  \n– Employees should provide accurate and truthful information in all business \ninteractions  \n– Avoid deceptive practices, including misleading advertising, and be transparent in \ncommunications  \n2. Integrity:',
#  '2. Integrity:  \n– Act ethically and uphold high moral principles in all business activities –  Avoid \nconflicts of interest and disclose any potential conflicts that may arise  \n3. Trustworthiness:  \n– Build trust with clients, customers, and colleagues by consistently delivering on',
#  'promises and commitments  \n– Safeguard confidential information and respect privacy  \n4. Respect for Others:  \n– Treat all individuals with dignity and respect, regardless of differences such as race, \ngender, ethnicity, or background',
#  "– Foster an inclusive and diverse work environment that values different perspectives  \n5. Responsibility:  \n– Take ownership of one's actions and decisions  \n– Consider the impact of decisions on stakeholders, including employees, customers, \nand the community  \n6. Accountability:",
#  '– Hold oneself accountable for personal and professional behavior  \n– Admit mistakes, learn from them, and take corrective actions when necessary  \n7. Reliability:  \n– Consistently deliver quality products and services',
#  '– Honor commitments and deadlines, and communicate proactively if challenges arise  \n8. Obedience to the Law:  \n– Conduct business in compliance with all applicable laws and regulations    \n  \n  – Foster a culture of legal and ethical behavior and report any illegal activities promptly',
#  '9. Professional Development:  \n– Encourage continuous learning and development to enhance professional \ncompetence  \n– Stay informed about industry standards and best practices  \n10. Environmental and Social Responsibility:  \n– Promote environmentally sustainable practices',
#  '– Contribute positively to the communities in which the business operates  \n11. Conflict Resolution:  \n– Encourage open communication to resolve conflicts in a constructive and respectful \nmanner  \n– Seek mediation or other appropriate channels when conflicts arise  \n12. Whistleblower Protection:',
#  '– Provide protection and support for employees who report unethical behavior or \nviolations of the Code of Ethics  \n– Establish clear channels for reporting, investigation, and resolution of ethical concerns     \n  4. Ethical Decision Making',
#  'At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set \nof core values that form the foundation of our business conduct. These principles reflect who \nwe are as an organization and shape our interactions with clients, co lleagues, and the \nbroader community.',
#  '1. Legal Compliance:  \n– Ensure that your actions are not only aligned with our values but also comply with all \nrelevant laws and regulations  \n2. Alignment with Company Values:  \n– Uphold our company values and ethical principles in every decision and action,',
#  "contributing to a workplace culture rooted in integrity  \n3. Adherence to Code and Policies:  \n– Follow our Code of Ethics and company policies diligently, providing a foundation for \nethical behavior within the organization  \n4. Respect for Others' Rights:",
#  '– Always consider the rights and well -being of others in your actions, fostering a \nworkplace characterized by respect and empathy  \n5. Reputational Consideration:  \n– Envision how your decisions would be perceived if they were to make headlines.',
#  'Uphold our reputation by making choices that reflect positively on EnFuse  \n6. Loyalty to Stakeholders:  \n– Demonstrate loyalty to your colleagues, your family, and yourself by making decisions \nthat prioritize long -term well -being over short -term gains  \n7. The Right Thing to Do:',
#  "– Embrace the question 'Is this the right thing to do?' as a guiding principle, ensuring \nthat your actions align with your moral compass  \n8. Resistance to Misrepresentation:  \n– Stand firm in your commitment to integrity. If asked to misrepresent information or",
#  'deviate from normal procedures, resist and uphold the values that define EnFuse.  \n5. Compliance with Laws & Regulations  \n \nOur commitment to integrity begins with complying with laws, rules and regulations. We \nunderstand and comply with the legal requirements and commercial practices of lawful',
#  'business.    \n  \n  We are committed to adhere to every valid and binding contractual agreement that we \nconclude, and we do not abuse our rights.  \n▪ Companies Act, 2013 (India):  We being a public company ensure compliance with the',
#  'Companies Act. This includes aspects like corporate governance, financial reporting, \nand meeting disclosure requirements. Our code of conduct could address ethical \npractices in these areas, such as prev enting insider trading and maintaining accurate \nfinancial records.',
#  '▪ SEBI (ICDR) Regulations, 2018:  As a company listed on the National Stock Exchange (NSE),  \nEnFuse Solutions adheres to regulations set by the Securities and Exchange Board of India \n(SEBI). These regulations focus on protecting investor interests through transparent',
#  "disclosures and fair market practices.  \n▪ Labor Laws:  Indian labor laws mandate fair wages, safe working conditions, and \nadherence to working hours. EnFuse Solutions' code reflects their commitment to these \naspects.",
#  'aspects.  \n▪ Data Privacy:  With our focus on data management and analytics, EnFuse Solutions has a \nrobust data privacy policy aligned with Indian regulations. Our code emphasizes \nresponsible data handling and user privacy protection.',
#  '▪ Intellectual Property:  The code might address respecting intellectual property rights of \nboth EnFuse Solutions and their clients.  \nA strong code of conduct policy that aligns with relevant laws and regulations demonstrates',
#  "EnFuse Solutions' commitment to ethical business practices. This enables building trust with \nstakeholders and investors.   \nOur staff must follow applicable laws and regulations, including the Code of Ethics and \nBusiness Conduct at all times and must ensure compliant operation .",
#  '6. Human Rights  \nWe are committed to respect human dignity and rights of each individual and community \nwhom we interact with during the course of work. We shall not, in any way, cause or \ncontribute to the violation of human rights. Our staff shall treat everybody with dign ity,',
#  'respect and care and uphold human rights.     \n  \n  7. Fair Labour Practices & Working Conditions  \n \nWe are committed to promote equality in our employment practices and to fair employment \nand remuneration policy in compliance with applicable laws. We are firmly opposed to',
#  'employing or contracting child or slave labour or any form of forced or compulsory or \nbonded labour. We condemn all forms of illegal, unfair, unethical labour practice that \nexploits workforce, destroys social security or serves as tax evasion, including but not limited',
#  'to undeclared and “grey” work or holding back wages.  \nOur staff shall act with integrity and treat their colleagues and others through the work with \nfull respect.     \n  \n  8. Discrimination & Harassment  \nWe provide equal opportunity in employment and we do not tolerate any discrimination or',
#  'harassment or any type of abuse. No direct or indirect discrimination shall take place based \non any professionally non -relevant trait or circumstance, like gender, mari tal status, age, \nnational or social or ethnic origin, colour, religion and political opinion, disability, sexual',
#  'orientation, employee representation, property, birth or other status. Any kind of \ndiscriminatory behaviour, harassment, bullying or victimizat ion is prohibited.  \nAll staff are expected to follow the highest standards of conduct in all verbal and written',
#  'communication based on mutual respect, and must refrain from any form of harassment, \nslander or any behaviour that could be taken as offensive, intimidating, humili ating, malicious \nor insulting.     \n  \n  9. Health, Safety & Environment',
#  'We provide clean, safe and healthy work conditions and we are dedicated to maintaining a \nhealthy environment. We are committed to minimise the impact on the natural environment \nof our operations. We make efforts to reduce the use of finite resources, like energy or water,',
#  'and the harmful emissions, like waste.  \nAll staff must follow and comply with every relevant health, safety and environmental \nprotection laws, regulations and rules all times.    \n  \n  10. Fair Competition & Business Conduct',
#  'Our relationships with business partners are built upon trust and mutual benefits compliant \nwith competition law. We are dedicated to ethical and fair competition, as we sell services \nbased on their quality, functionality and competitive pricing. We will m ake independent',
#  'pricing and marketing decisions and will not improperly cooperate or coordinate our \nactivities with our competitors. We will not offer or solicit improper payments or gratuities, nor \nwill we engage or assist in unlawful boycotts of particul ar customers. We commit to comply',
#  'with all applicable trade controls, restrictions, sanctions and import -export embargoes.  \nWe do not allow any violence of the fairness of any tendering process in any way. We refrain \nfrom damaging competition and the reputation of any business partners and any behaviour',
#  'that harms competitor’s credibility.   \nWe do not hold back maliciously, unlawfully or unduly payments towards our partners, and \nwe do not allow such practices in our supply chain, we fight the unethical practice of “debt \nchain”.',
#  'chain”.  \nOur staff is responsible for ensuring fair business during their job and adhere to every \ncompetition, consumer protection and fair marketing rule. Customers and business partners \nshall be treated fairly and equally, products and services shall be displayed  in a manner that',
#  'is fair and accurate (fair marketing and advertising), and that discloses all relevant \ninformation.     \n  \n  11. Anti-corruption  \n \nWe firmly condemn and do not tolerate all forms of corruption. It is prohibited directly or',
#  'indirectly offering, promising, giving, asking, soliciting or accepting any unfair advantage or \nbenefit, in order to obtain, retain or facilitate in any way the bus iness. An unfair advantage \nor benefit may include cash, any cash equivalent (e.g. voucher), gift, credit, discount, travel,',
#  'personal advantage, accommodation or services. We do not permit facilitation (or \n“grease”) payments to government officials or priva te business in order to secure or speed \nup routine actions. Corruption also covers the misuse of function or position as well, when',
#  'someone makes that false appearance that s/he improperly influences a decision maker.  \nCorruption for either to obtain or retain business, or to obtain or retain an advantage in the \nconduct of business is considered gross misconduct. Similarly accepting or allowing another',
#  'person to accept a bribe is considered gross misconduct. Our staff’s has to account for all \nbenefits received in the course of doing business and must to not give or receive bribes or \notherwise act corruptly.     \n  \n  12. Gifts & Hospitality',
#  'We shall avoid any actions that create a perception that favourable treatment was sought, \nreceived or given in exchange for personal benefits.  \nBusiness courtesies or benefits include gifts, gratuities, meals, refreshments, entertainment or',
#  'other advantages from persons or companies with whom we do or may do business. We will \nneither give nor accept such benefits that constitute, or could reasonab ly be perceived as \nconstituting, unfair business inducements that would violate law, regulation or policies, or',
#  'would cause embarrassment. Our staff may never use personal funds or resources to do \nsomething that cannot be done with our resources.  \nWe may accept and offer occasional gifts and hospitality that are customary and conform',
#  'to reasonable ethical practices of the market, provided that they are not inappropriately \nexcessive, not frequent and do not reflect a pattern of frequent acceptance, d oes not \ncreate the appearance of an attempt to influence business decisions. Only trivial gifts with',
#  'low value can be accepted. All other gifts must be politely refused or, if received through \npost, returned to the donor. If return is not possible it shall  be offered for charity or community \npurposes. It is the responsibility of the person offering, providing, receiving or accepting the',
#  'gift to decide whether the gift is appropriate.     \n  \n  13. Security, Protection & Proper Use of Company Assets  \n \nWe are responsible for the security, protection and for the economic use of company \nresources. Our resources, including time, material, equipment and information are provided',
#  'for legitimate business use only. Occasional personal use is permissible as long as it is lawful, \ndoes not affect job performance or disrupts workplace morale.  \nAll staff is obliged to follow appropriate security measures and they should treat company',
#  'property, whether material or intangible, with respect and shouldn’t misuse company assets \nor use it carelessly.     \n  \n  14. Confidentiality, Information Security, & Intellectual \nProperty  \n \nWe are committed to business information confidentiality, integrity and accessibility, we',
#  'implement proper technical security measures and it is our staff’s obligation to uphold this. \nProprietary information includes all non -public information that might b e harmful to the \ncompany or its customers, business partners if disclosed to unauthorised parties. All staff must',
#  'handle any such information as secret. It also covers that, no one is entitled to trade with \nsecurities while in possession of non -public info rmation or deliver non -public information to \nothers that could have an impact on the securities. Every rule ensuring information security',
#  'must be followed all the time.  \nWe respect the property rights of others. We will not acquire or seek to acquire trade secrets \nor other proprietary or confidential information by improper means. We will not engage in',
#  'unauthorized use, copying, distribution or alteration of software or ot her protected \nintellectual property.     \n  \n  15. Bookkeeping, True Reporting & Financial Integrity  \n \nOur books, records, accounts and financial statements must be maintained in appropriate',
#  'detail, must truly and properly reflect our transactions. We condemn all forms of money \nlaundering, so we are committed to do business with partners involved in legitim ate business \nactivities with funds derived from legitimate sources.',
#  'We commit ourselves to fair taxation and to avoid all tax evasion practices, including such as \nfailing to issue receipt or accounting fake expense invoices.  \nAll staff must follow accounting procedures, ensure that business transactions are recorded',
#  'and documented appropriately and make certain that all disclosures made in financial \nreports are full, honest, accurate, timely and understandable. All staff must n ot improperly \ninfluence, manipulate or mislead any audit.    \n  \n  16. Anti-fraud',
#  '16. Anti-fraud  \nFraud – the act or intent to cheat, steal, deceive or lie – is both unethical and, in most cases, \ncriminal. Fraud in every form, (including e.g. submitting false expense reports; forging or \naltering financial documents or certifications; misappropriation of assets or misusing',
#  'company property; making any untrue fin ancial or non -financial entry on records or \nstatements) is prohibited.     \n  \n  17. Conflict of Interests  \nOur decisions shall be based on objective and fair assessments avoiding the possibility of any',
#  'improper influence. A "conflict of interest" exists when an employee\'s personal interest (that \ncan be linked to e.g. friends, family, or customer, competitor, su pplier, contractor entity, as \nwell) interferes or potentially interferes with the best interests of EnFuse. Determining whether',
#  'a conflict of interest exists is not always easy to do, thus anyone with a conflict of interest \nquestion should seek advice from  management.  \nConflicts of interest could arise:  \n▪ Being employed (you or a close family member) by, or being in economic relation with',
#  'an actual or potential customer, competitor, supplier or contractor  \n▪ Hiring or supervising family members or closely related persons  \n▪ Serving as a board member for another company or organization  \n▪ Owning or having a substantial interest in a customer, competitor, supplier or contractor',
#  '▪ Having a personal interest, financial interest or potential personal gain in any company \ntransaction    \n  \n  If co -workers become involved in personal relations with each other, the onus is on the senior \nemployee concerned to bring this to the attention of his or her manager to confirm that',
#  'there is no conflict of interest, nor will a conflict of interest arise.     \n  \n  18. Privacy, Personal Data Protection  \n \nWe respect people’s privacy and we acknowledge customers, employees and other natural',
#  'persons’ need to feel confident that their personal data is processed appropriately and for a \nlegitimate business purpose. We are committed to comply with all personal data protection \nlaws. We only acqu ire and keep personal information that is necessary and we give proper',
#  'information on these activities to data owners. We implement proper security measures to \nassure confidentiality, integrity and availability of personal information.  \nOur staff must observe the legal requirements, apply compliant practices and follow related',
#  'procedures to ensure legality of personal data handling and processing activities.     \n  \n  18. Employee Acceptance  \nI have read and understood the EnFuse Solutions’s Code of Ethics and Business Conduct and \nI agree to comply with the statements contained within.',
#  'Employee Name:  –––––––––––––––––––––––––––––––––––––––––––––––––––––––––   \nEmployee ID:  –––––––––––––––––––––––––––––––––––––––––––––––––––––––––   \n    \n    \nEmployee Signature:  –––––––––––––––––––––––––––––––––––––––––––––––––––––––––',
#  'Date of Acknowledgement:  –––––––––––––––––––––––––––––––––––––––––––––––––––––––––',
#  'Leave Policy  \n \nPolicy Document  \n1. Introduction  \n \n1.1.  Objectives  \nThis guideline outlines the leaves available for Full -time and Contract employees of EnFuse \nSolutions Ltd. It also outlines employee eligibility, leave application process, carry over and \ntreatment of unused leaves.',
#  '1.2.  Scope and Applicability  \nThis guideline applies to all employees and probationers of EnFuse Solutions. The annual \nleave calendar runs from April 1st and ends on March 31st.   \n  \n  \n    \n  2. Leaves for Full -time Regular Employees',
#  "At the start of every month, 2 paid leaves will be accrued to the employee's leave account \nfor joiners between 1st and 15th and 1 paid leave will be accrued to the employee's leave \nbalance account for joiners between 16th to 30th/31st. If the leave is not availed in a month,",
#  'the same shall be carried forward to the next month.  \n▪ The Employee is entitled to two days off in a week (5 working days)  \n▪ Employee is entitled to 24 days of paid personal leaves in a year. Employees are',
#  'encouraged to take appropriate leaves during the year to maintain a work -life balance.  \n▪ All accrued personal leaves shall be utilized before the end of the financial year as any \nunused leaves beyond 12 leaves will lapse at the end of the financial year. A maximum',
#  'of 12 unused leaves to be carried forward for the next financial year.  \n▪ The Employee cannot carry forward or encash any Public holiday/leave to the next \ncalendar year  \n▪ All the leaves are to be applied on Zoho and approved by the respective Manager  \n2.1.  Planned Leaves',
#  'For planned leaves of more than 1 day, the employee must intimate the same to the \nreporting manager at least 1 week in advance and follow the stipulated procedure for leave \napplication.  \n2.2.  Unplanned Leaves',
#  'Suppose the employee is absent from work due to sickness or emergency. In that case, they \nwill follow the Leave Policy, inform the reporting manager as soon as possible, provide regular \nupdates, and, as far as practicable, inform of their expected date of return to work. For a',
#  'leave of more than 2 days, a medical certificate from a licensed medical practitioner will be \nrequired to be submitted to the reporting manager.  \n2.3.  Continuous Absence -Absconding Initiation  \nAn employee absent without prior permission from work for more than 5 consecutive working',
#  "days shall be deemed to have left the company's services on their own accord (absconding \ncase), and the necessary process will be followed for termination of employme nt.  \nFor corrective measures understanding, please refer to the Attendance and Punctuality \nPolicy.  \n2.4.  Leave Application",
#  '▪ Employees should plan and notify their reporting managers about the leave days in \nadvance except in case of emergencies.    \n  ▪ All leave requests are to be submitted through Zoho and should be approved by the \nrespective managers. In case of unwell employees or circumstances where an employee',
#  'cannot apply for leave on Zoho, the immediate manager can raise a leave request on \nbehalf of the employee.  \n3. Maternity Leave  \n \nMaternity Leave (ML) is governed by the Maternity Benefit Act 1961 and Maternity Benefit \n(Amendment) Act 2017.  \nEligibility:',
#  'Eligibility:  \nThis policy applies only to women employees of EnFuse Solutions Ltd working on Full -time \npayroll for at least 80 days within the past 12 months. Contract Women employees are not \neligible.  \nApplicability:',
#  'Applicability:  \nEligible employees will be entitled to a maximum of 26 weeks of leave during the tenure of \nservice.  \nOf the 26 weeks an employee is entitled to, the employee can avail of the maternity leave',
#  'no more than 8 weeks prior to the date of her expected delivery for the first two childbirths.  \nAn employee with more than two surviving children shall be entitled to maternity benefit for \n12 weeks, of which no more than 6 weeks shall precede the date of the expected delivery \nfor childbirth.',
#  'for childbirth.  \nPrior to proceeding on leave, the employee must give written notice of at least four weeks in \nadvance to the business management and HR. This is required to enable the other teams in \nthe division to plan and allocate work accordingly.',
#  "Full salary will be paid for twenty -six weeks provided that the incumbent does not undertake \nany other form of employment/vocation during this period and that the child's birth is notified \nto and certified by a registered medical practitioner.",
#  "If further extension of leave is required, it will be given only on a case -to-case basis at the \nmanagement's discretion. An employee can extend the leave only to the extent of available \nleave balance post which leaves are treated as leave without pay.",
#  'All benefits per the provisions of Maternity Benefit Act which includes miscarriage, illness \narising out of pregnancy, delivery, premature birth of child (including Still birth) or \nmiscarriage. In case of any inconsistency or conflict with this leave polic y and the Act, the',
#  "Act's provisions shall override.  \nNo payment shall be due or payable instead of unused maternity leave.  \nRelevant documentation to be submitted, such as Sonography report, doctor \nrecommendation letter, and leave application for Maternity Leave application. Format to be \ntaken from HR POC.",
#  '3.1.  Paternity Leave  \nMale employees are eligible for 5 days of Paternity Leave (PAT) for 2 newborn children.  \nPaternity leave can be used flexibly within the first three months of childbirth.  \n   \n  \n3.2.  Childcare Leave',
#  'Unpaid childcare leave may be granted on a request basis for new mothers returning from \nmaternity leave. The leave grant would be on request basis and the valid document \nsubmission is mandatory.  \n3.3.  Adoption Leave',
#  'A female employee who legally adopts a child or commissioning mother shall be entitled to \nadoption leave for 12 weeks from the date the child is handed over to the adopting mother \nor the commissioning mother as per the provisions of the Maternity Benefit A ct.',
#  "For a male employee who legally adopts a child, 5 days leave will be granted where the \nadopted child's age is up to 3 years. This allowance is up to 2 children - biological or \nadopted. If the male employee is a single parent and has adopted the child, 12 w eeks of \nleave will be granted.",
#  '3.4.  Public Holidays  \nAll employees are eligible for 11 public holidays each calendar year. A public holiday list is \ndeclared every year. Employees based at Client Sites are governed by the Public Holidays \nguidelines as announced by their Project sites and Client sites.',
#  '3.5.  Encashment of Leaves  \nIn case of separation (voluntary & involuntary) of an employee from services for whatsoever \nreason, there will be encashment of leave balance accrued during the year, provided the',
#  'employee meets all other terms and conditions of employment. Adjustment of l eave, against \nnotice period, on resignation, is subject to acceptance by the reporting manager.  \n4.  Leave Policy for Contractual Employee',
#  'Leave Policy for Contractual Employee (Designation Entitlement as STP -Consultant)  \nThe temporary employees are entitled to 2 day -off in a week (5 working days) and any 11 \npublic holiday falls during their tenure at EnFuse Solutions.',
#  'Post 2 weeks of completion of the probationary period, the temporary employees would be \nentitled to 1 paid leave per month. They must follow the guideline for leave application (if \nneeded), similar to full -time employees.',
#  "▪ For 1 day's leave: A leave request must be raised at least 24 hours before the leave start \ntime    \n  ▪ For 2 -3 days' leave: A leave request must be submitted at least 3 days before the leave \nstart day",
#  "start day  \n▪ For 4 -5 day's leave: A leave request must be submitted at least 6 days before the leave \nstart day  \n▪ 5 or more leaves: A leave request must be submitted at least 10 days before the leave \nstart day"]

# %%
import faiss

index_file_path = 'D:\RAG\embeddings\hr_policy_faiss.index'

try :
    index = faiss.read_index(index_file_path)
    print(index)
except Exception as e:
    print("Error")
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x000001C883F999B0> >
# <>:3: SyntaxWarning: invalid escape sequence '\R'
# <>:3: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\kartik.rathi_enfuse-\AppData\Local\Temp\ipykernel_20900\4147879976.py:3: SyntaxWarning: invalid escape sequence '\R'
#   index_file_path = 'D:\RAG\embeddings\hr_policy_faiss.index'

# %% [markdown]
# # MODEL EVALUATION USING RAGAs

# %%
from src.pdf_extraction import extract_text_from_pdf, extract_text_from_pdfs

data = extract_text_from_pdfs(r'./Data')
# Out:
# Processing file: Attendance and Punctuality_final.pdf
# Processing file: Compensatory Off Policy_final.pdf
# Processing file: Confirmation Policy-new.pdf
# Processing file: EnFuse - Code of Conduct_July24 CS (1)_new.pdf
# Processing file: Leave Policy_Updated_new.pdf

# %%
source_text = data[4]
source_text
# Out:
# " \n Leave Policy  \n \nPolicy Document  \n1. Introduction  \n \n1.1.  Objectives  \nThis guideline outlines the leaves available for Full -time and Contract employees of EnFuse \nSolutions Ltd. It also outlines employee eligibility, leave application process, carry over and \ntreatment of unused leaves.  \n1.2.  Scope and Applicability  \nThis guideline applies to all employees and probationers of EnFuse Solutions. The annual \nleave calendar runs from April 1st and ends on March 31st.   \n  \n  \n    \n  2. Leaves for Full -time Regular Employees  \n \nAt the start of every month, 2 paid leaves will be accrued to the employee's leave account \nfor joiners between 1st and 15th and 1 paid leave will be accrued to the employee's leave \nbalance account for joiners between 16th to 30th/31st. If the leave is not availed in a month, \nthe same shall be carried forward to the next month.  \n▪ The Employee is entitled to two days off in a week (5 working days)  \n▪ Employee is entitled to 24 days of paid personal leaves in a year. Employees are \nencouraged to take appropriate leaves during the year to maintain a work -life balance.  \n▪ All accrued personal leaves shall be utilized before the end of the financial year as any \nunused leaves beyond 12 leaves will lapse at the end of the financial year. A maximum \nof 12 unused leaves to be carried forward for the next financial year.  \n▪ The Employee cannot carry forward or encash any Public holiday/leave to the next \ncalendar year  \n▪ All the leaves are to be applied on Zoho and approved by the respective Manager  \n2.1.  Planned Leaves  \nFor planned leaves of more than 1 day, the employee must intimate the same to the \nreporting manager at least 1 week in advance and follow the stipulated procedure for leave \napplication.  \n2.2.  Unplanned Leaves  \nSuppose the employee is absent from work due to sickness or emergency. In that case, they \nwill follow the Leave Policy, inform the reporting manager as soon as possible, provide regular \nupdates, and, as far as practicable, inform of their expected date of return to work. For a \nleave of more than 2 days, a medical certificate from a licensed medical practitioner will be \nrequired to be submitted to the reporting manager.  \n2.3.  Continuous Absence -Absconding Initiation  \nAn employee absent without prior permission from work for more than 5 consecutive working \ndays shall be deemed to have left the company's services on their own accord (absconding \ncase), and the necessary process will be followed for termination of employme nt.  \nFor corrective measures understanding, please refer to the Attendance and Punctuality \nPolicy.  \n2.4.  Leave Application  \n▪ Employees should plan and notify their reporting managers about the leave days in \nadvance except in case of emergencies.    \n  ▪ All leave requests are to be submitted through Zoho and should be approved by the \nrespective managers. In case of unwell employees or circumstances where an employee \ncannot apply for leave on Zoho, the immediate manager can raise a leave request on \nbehalf of the employee.  \n3. Maternity Leave  \n \nMaternity Leave (ML) is governed by the Maternity Benefit Act 1961 and Maternity Benefit \n(Amendment) Act 2017.  \nEligibility:  \nThis policy applies only to women employees of EnFuse Solutions Ltd working on Full -time \npayroll for at least 80 days within the past 12 months. Contract Women employees are not \neligible.  \nApplicability:  \nEligible employees will be entitled to a maximum of 26 weeks of leave during the tenure of \nservice.  \nOf the 26 weeks an employee is entitled to, the employee can avail of the maternity leave \nno more than 8 weeks prior to the date of her expected delivery for the first two childbirths.  \nAn employee with more than two surviving children shall be entitled to maternity benefit for \n12 weeks, of which no more than 6 weeks shall precede the date of the expected delivery \nfor childbirth.  \nP ...

# %%
from src.chunking import split_text_into_chunks

new = split_text_into_chunks(source_text)
new
# Out:
# ["Compensatory Off Policy  \n \n1.  Compensatory Off Policy  \n \n1.1.  Introduction  \nThe Compensatory Off Policy document aims to define EnFuse's approach to the concept of  \nCompensatory policy. This document will act as a guideline, and it is expected that all the \nEnFusians abide by the same.",
#  '1.2.  Definition of Compensatory Off  \nAlso known as Comp Off, Compensatory Off is an optional way of providing leave to \nemployees who work on a holiday or a week off. The Compensatory Off policy provides \nemployees with leaves to be compensated by a holiday or a week off work. Any such',
#  'approved  Holiday / Week off working would be marked as a compensatory off in the system. \nIt can be availed during the eligibility period (provided all the eligibility / validity criteria are \nqualifying).  \n1.3.  Eligibility for Applying for Compensatory Off',
#  'The Employees can only apply for Compensatory Off if they fulfill the following two criteria:  \n▪ The Employee should have worked for One Full Day - On account of a project \nrequirement pre -approved by the respective Manager  \n▪ The Employee should be a Full -time resource',
#  "1.4.  Compensatory Off Process Flow  \nFollowing process allows the employees to add a request for a compensatory off:  \nAdd Compensatory Request.  \n▪ Login to Zoho People Account  \n▪ Go to 'Leave Tracker' and click on 'Compensatory Request'  \n▪ Click on '+Add Request'",
#  "– Fill in all the following details:  \n– a. Employee Name  \n– b. Worked Date  \n– c. Add Description in the box (write specifically about project you worked on)  \n▪ Click on 'Submit'  \n      Once the request is submitted, respective managers will give approval to the same.",
#  "After the request is approved, it reflects in the Compensatory Off list, where you can review the \ncount of compensatory offs.   \n▪ Go to 'Leave Tracker' and click on 'List View'  \nThe List View will appear, and one can see the approved and pending Compensatory offs.  \nAvailing Compensatory Off:",
#  "▪ Click on 'Compensatory Off' in List View  \n▪ Add the details asked:  \n– Date  \n– Reason for leave  \n– And click on 'Submit'  \n1.5.  Validity of Compensatory Off  \nAny approved Compensatory Off is valid for 365 days from the date of approval. Manager to",
#  'approve the Comp Off within a week of the date of week off working / Holiday working.  \n1.6.  Exceptions Management  \nAny exceptions to the Compensatory Off policy to be approved HR L ead.']

# %%
from huggingface_hub import login
login(token = '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')

# %%
import random
from transformers import pipeline, T5Tokenizer

tokenizer = T5Tokenizer.from_pretrained("wiselinjayajos/t5-end2end-questions-generation")
# Initialize the question-generation pipeline
question_generator = pipeline("text2text-generation", model="wiselinjayajos/t5-end2end-questions-generation")
# Out:
# Device set to use cpu

# %%
# Function to generate synthetic data from a list of text fragments
def generate_synthetic_data(source_text_list, max_questions_per_text=10):
    synthetic_data = []

    for source_text in source_text_list:
        # Split the text into logical chunks (e.g., paragraphs or sections)
        source_data = source_text.split('\n\n')

        for i, item in enumerate(source_data):
            if max_questions_per_text is not None and i >= max_questions_per_text:
                break

            # Generate a question based on the paragraph/section
            generated = question_generator(f"generate question: {item}", max_length=64, num_return_sequences=1)
            question = generated[0]['generated_text']

            # Use the paragraph/section as context and extract a ground truth answer
            context = item
            answer = "Not specified"  # Replace with a more sophisticated answer extraction logic if needed

            synthetic_data.append({
                "question": question,
                "context": context,
                "ground_truth": answer
            })

    return synthetic_data

# Generate synthetic dataset with a maximum of 10 questions per text fragment
synthetic_dataset = generate_synthetic_data(new, max_questions_per_text=10)

# Display the generated questions and context
for i, item in enumerate(synthetic_dataset, 1):
    print(f"Sample {i}:")
    print(f"  Question: {item['question']}")
    print(f"  Context: {item['context']}\n")
    print(f"  Ground Truth: {item['ground_truth']}\n")
# Out:
# Sample 1:
#   Question: What is the name of the document that defines EnFuse's approach to the concept of Compensatory policy? What is the name of the document that defines EnFuse's approach to the concept of Compensatory policy? What is the name of the document that defines EnF
#   Context: Compensatory Off Policy
#
# 1.  Compensatory Off Policy
#
# 1.1.  Introduction
# The Compensatory Off Policy document aims to define EnFuse's approach to the concept of
# Compensatory policy. This document will act as a guideline, and it is expected that all the
# EnFusians abide by the same.
#
#   Ground Truth: Not specified
#
# Sample 2:
#   Question: What is an optional way of providing leave to employees who work on a holiday or a week off? What is an optional way of providing leave to employees who work on a holiday or a week off? What is an optional way of providing leave to employees who work on a holiday or
#   Context: 1.2.  Definition of Compensatory Off
# Also known as Comp Off, Compensatory Off is an optional way of providing leave to
# employees who work on a holiday or a week off. The Compensatory Off policy provides
# employees with leaves to be compensated by a holiday or a week off work. Any such
#
#   Ground Truth: Not specified
#
# Sample 3:
#   Question: What would be marked as a compensatory off in the system? What can be availed during the eligibility period?
#   Context: approved  Holiday / Week off working would be marked as a compensatory off in the system.
# It can be availed during the eligibility period (provided all the eligibility / validity criteria are
# qualifying).
# 1.3.  Eligibility for Applying for Compensatory Off
#
#   Ground Truth: Not specified
#
# Sample 4:
#   Question: What are the two criteria that an Employee must meet to be eligible for Compensatory Off? What should the Employee have worked for? What should the Employee be a Full-time resource?
#   Context: The Employees can only apply for Compensatory Off if they fulfill the following two criteria:
# ▪ The Employee should have worked for One Full Day - On account of a project
# requirement pre -approved by the respective Manager
# ▪ The Employee should be a Full -time resource
#
#   Ground Truth: Not specified
#
# Sample 5:
#   Question: What is the following process that allows employees to add a request for a compensatory off? What is the following process? What is the following process?
#   Context: 1.4.  Compensatory Off Process Flow
# Following process allows the employees to add a request for a compensatory off:
# Add Compensatory Request.
# ▪ Login to Zoho People Account
# ▪ Go to 'Leave Tracker' and click on 'Compensatory Request'
# ▪ Click on '+Add Request'
#
#   Ground Truth: Not specified
#
# Sample 6:
#   Question: What is the name of the employee? What is the work date? What is the description of the project? What will the respective managers give approval to?
#   Context: – Fill in all the following details:
# – a. Employee Name
# – b. Worked Date
# – c. Add Description in the box (write specifically about project you worked on)
# ▪ Click on 'Submit'
#       Once the request is submitted, respective managers will give approval to the same.
#
#   Ground Truth: Not specified
#
# Sample 7:
#   Question: What is the name of the list where you can review the count of compensatory offs? What is the name of the list where you can see the approved and pending Compensatory offs? What is the name of the list where you can review the count of compensatory offs?
#   Context: After the request is approved, it reflects in the Compensatory Off list, where you can review the
# count of compensatory offs.
# ▪ Go to 'Leave Tracker' and click on 'List View'
# The List View will appear, and one can see the approved and pending Compensatory offs.
# Availing Compensatory Off:
#
#   Ground Truth: Not specified
#
# Sample 8:
#   Question: What is the term for the validity of Compensatory Off? What is the term for the validity of Compensatory Off? What is the term for the validity of Compensatory Off? What is the term for the validity of Compensatory Off?
#   Context: ▪ Click on 'Compensatory Off' in List View
# ▪ Add the details asked:
# – Date
# – Reason for leave
# – And click on 'Submit'
# 1.5.  Validity of Compensatory Off
# Any approved Compensatory Off is valid for 365 days from the date of approval. Manager to
#
#   Ground Truth: Not specified
#
# Sample 9:
#   Question: How long must the Comp Off be approved? What is the minimum time to approve the Comp Off?
#   Context: approve the Comp Off within a week of the date of week off working / Holiday working.
# 1.6.  Exceptions Management
# Any exceptions to the Compensatory Off policy to be approved HR L ead.
#
#   Ground Truth: Not specified

# %% [markdown]
# # RAGAS EVALUATION

# %% [markdown]
# i have questions in excel file and now i want to store the context and answers in that for evaluations

# %%
#Load FAISS index and metadata
from src.embedding import load_faiss_index, load_metadata
from src.retrieval import retrieve_relevant_chunks
from src.qa import create_llm_chain, get_answer

faiss_index_path = r'D:\RAG\embeddings\hr_policy_faiss.index'
metadata_path = r'D:\RAG\embeddings\hr_policy_faiss_metadata.pkl'
index = load_faiss_index(faiss_index_path)
metadata = load_metadata(metadata_path)
""
query = " Under what conditions can an employee apply for Compensatory Off? "
#Retrieve relevant chunks based on the query
retrieved_chunks = retrieve_relevant_chunks(query, index, metadata, top_k=2)
print(retrieved_chunks)

print("==========================================")

# LLM answer generation
# Step 7: Get the answer using the retrieved context
llm_chain = create_llm_chain()
context = "\n".join([chunk for chunk, _ in retrieved_chunks])
answer = get_answer(llm_chain, context, query)
output = answer['text']
print(output)
# Out:
# [('The Employees can only apply for Compensatory Off if they fulfill the following two criteria:  \n▪ The Employee should have worked for One Full Day - On account of a project \nrequirement pre -approved by the respective Manager  \n▪ The Employee should be a Full -time resource', 0.3624244), ('approved  Holiday / Week off working would be marked as a compensatory off in the system. \nIt can be availed during the eligibility period (provided all the eligibility / validity criteria are \nqualifying).  \n1.3.  Eligibility for Applying for Compensatory Off', 0.59751034)]
# ==========================================
# d:\RAG\src\qa.py:33: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   return LLMChain(llm=hf_model, prompt=prompt)
#  An employee can apply for Compensatory Off if they have worked for one full day on account of a project requirement pre-approved by their respective manager and are a full-time resource. The holiday/week off working would be marked as a compensatory off in the system and can be availed during the eligibility period.

# %% [markdown]
# # Code to get testing excel sheet

# %%
import pandas as pd
from src.embedding import load_faiss_index, load_metadata
from src.retrieval import retrieve_relevant_chunks
from src.qa import create_llm_chain, get_answer

# Load FAISS index and metadata
faiss_index_path = r'D:\RAG\embeddings\hr_policy_faiss.index'
metadata_path = r'D:\RAG\embeddings\hr_policy_faiss_metadata.pkl'

# Load the FAISS index and metadata
faiss_index = load_faiss_index(faiss_index_path)  # Rename the FAISS index variable
metadata = load_metadata(metadata_path)

# Load the Excel file containing the queries
excel_path = r'C:\Users\kartik.rathi_enfuse-\Desktop\test_data.xlsx'
df = pd.read_excel(excel_path)

# Initialize the LLM chain
llm_chain = create_llm_chain()

# Process each query in the 'Ques' column
for idx, row in df.iterrows():  # Use a different name for the DataFrame index (e.g., idx)
    query = row['Ques']

    # Retrieve relevant chunks based on the query using the FAISS index
    retrieved_chunks = retrieve_relevant_chunks(query, faiss_index, metadata, top_k=2)
    context = "\n".join([chunk for chunk, _ in retrieved_chunks])

    # Get the answer using the retrieved context
    answer = get_answer(llm_chain, context, query)
    output = answer['text']

    # Store the context and answer in the DataFrame
    df.at[idx, 'Context'] = context
    df.at[idx, 'Answer'] = output

# Save the updated DataFrame to the Excel file
df.to_excel(r'D:\RAG\queries_with_answers.xlsx', index=False)

print("Processing completed. Results saved to 'queries_with_answers.xlsx'.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 from src.embedding import load_faiss_index, load_metadata
#       3 from src.retrieval import retrieve_relevant_chunks
# ----> 4 from src.qa import create_llm_chain, get_answer
#       6 # Load FAISS index and metadata
#       7 faiss_index_path = r'D:\RAG\embeddings\hr_policy_faiss.index'
#
# ImportError: cannot import name 'get_answer' from 'src.qa' (d:\RAG\src\qa.py)

# %% [markdown]
# # Evaluation

# %%
from ragas import SingleTurnSample
from ragas.metrics import NonLLMContextPrecisionWithReference

context_precision = NonLLMContextPrecisionWithReference()

sample = SingleTurnSample(
    retrieved_contexts=["The Eiffel Tower is located in Paris."], 
    reference_contexts=["Paris is the capital of France.", "The Eiffel Tower is one of the most famous landmarks in Paris."]
)

await context_precision.single_turn_ascore(sample)
# Out:
# 0.9999999999

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from deepeval.models.base_model import DeepEvalBaseLLM

class Mistral7B(DeepEvalBaseLLM):
    def __init__(
        self,
        model,
        tokenizer
    ):
        self.model = model
        self.tokenizer = tokenizer

    def load_model(self):
        return self.model

    def generate(self, prompt: str) -> str:
        model = self.load_model()

        device = "cuda" # the device to load the model onto

        model_inputs = self.tokenizer([prompt], return_tensors="pt").to(device)
        model.to(device)

        generated_ids = model.generate(**model_inputs, max_new_tokens=100, do_sample=True)
        return self.tokenizer.batch_decode(generated_ids)[0]

    async def a_generate(self, prompt: str) -> str:
        return self.generate(prompt)

    def get_model_name(self):
        return "Mistral 7B"
# Out:
# d:\RAG\RAG\Lib\site-packages\deepeval\__init__.py:51: UserWarning: You are using deepeval version 2.0.5, however version 2.1.2 is available. You should consider upgrading via the "pip install --upgrade deepeval" command.
#   warnings.warn(

# %%
from tempfile import TemporaryDirectory
from transformers import AutoModelForCausalLM, AutoTokenizer

with TemporaryDirectory() as tmpdirname:

    model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-v0.1",torch_dtype="float32")
# tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.1")

# mistral_7b = Mistral7B(model=model, tokenizer=tokenizer)
# print(mistral_7b.generate("Write me a joke"))

# %% [markdown]
# # Query Rewriter

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os
load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
generation_config = {
        'temperature': 0,
        'max_output_tokens': 8000,
        'top_p': 0.2
    }
model = genai.GenerativeModel(model_name='gemini-pro', generation_config=generation_config)

# %%
query = "should any female employee have to submit any document to take the maternity leave "
prompt_jd = f"""
    "Rewrite the given user query to make it precise and specific for retrieving accurate information from a 
    retrieval-augmented generation (RAG) system. Focus on HR policies and include all relevant details to ensure clarity.

    Args:
        user_query (str): Original query {query} from the user.

    Returns:
        str: Rewritten query for accurate retrieval.
    """

    # Step 3: Generate response using the model
response_jd = model.generate_content([prompt_jd])
response_text = response_jd.parts

# %%
print(response_text[0].text)
# Out:
# Retrieve HR policies related to maternity leave for female employees, including any specific documentation requirements for taking leave.

# %% [markdown]
# # QA Chnage

# %%
import os
from langchain_huggingface import HuggingFaceEndpoint
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.output_parsers import StructuredOutputParser
from langchain_core.output_parsers import StrOutputParser


def chain_output(context, re_query, model_repo_id="mistralai/Mistral-7B-Instruct-v0.3"):

    os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

    hf_model = HuggingFaceEndpoint(
        repo_id=model_repo_id,
        task="text2text-generation"
        )


    prompt_template = """
    You are an AI assistant trained to answer questions about HR policies in structured format.
    Given the following context and user query, provide a concise and accurate answer.Dont include headlines.

    Context:
    {context}

    Query:
    {query}

    Answer:
    """

    prompt = PromptTemplate(
        input_variables=["context", "re_query"],
        template=prompt_template
    )

    chain = prompt | hf_model | StrOutputParser()

    return chain.invoke({'context': context, 'query': re_query})

# %%
re_query = "What Should we do to take more than 3 days leave"
context = '''start day   
    ▪ 5 or more leaves: A leave request must be submitted at least 10 days before the leave 
    start day
    ▪ For 1 day's leave: A leave request must be raised at least 24 hours before the leave start 
    time   
    ▪ For 2 -3 days' leave: A leave request must be submitted at least 3 days before the leave 
    start day   
    ▪ For 4 -5 day's leave: A leave request must be submitted at least 6 days before the leave
    the same shall be carried forward to the next month.   
    ▪ The Employee is entitled to two days off in a week (5 working days)   
    ▪ Employee is entitled to 24 days of paid personal leaves in a year. Employees are'''

print(chain_output(re_query=re_query, context=context))
# Out:
# 1. To take more than 3 days leave, a leave request must be submitted at least 3 days before the leave start date.
#     2. If the leave is for 4 - 5 days, the request must be submitted at least 6 days before the leave start date.
#     3. The leave shall be carried forward to the next month if not availed.
#     4. Ensure you have sufficient personal leaves (24 days in a year) for the requested leave duration.

# %% [markdown]
# # ReWrite Query

# %%
from dotenv import load_dotenv
import google.generativeai as genai
import os
load_dotenv()

    # Configure the Generative AI API
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

    # Define the generation configuration
generation_config = {
        'temperature': 0,
        'max_output_tokens': 8000,
        'top_p': 0.2
    }

    # Initialize the model
model = genai.GenerativeModel(model_name='gemini-pro', generation_config=generation_config)

# %% [markdown]
# ## Chunk

# %%
def extract_text_from_pdfs(pdf_folder):
    """Extract text from all PDFs in the folder."""
    all_text = []
    for filename in os.listdir(pdf_folder):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder, filename)
            print(f"Processing file: {filename}")
            pdf_text = extract_text_from_pdf(pdf_path)
            all_text.append(pdf_text)
    return all_text

# %%
import os
path = r"C:\Users\kartik.rathi_enfuse-\Documents\New_Project\Policies_chatbot\Data"
texts = extract_text_from_pdfs(path)
# Out:
# Processing file: Acceptable Use Policy (1)_new.pdf
# Processing file: Attendance and Punctuality_new1.pdf
# Processing file: Compensatory Off Policy_new.pdf
# Processing file: Confirmation Policy_new.pdf
# Processing file: Diversity and Inclusion Policy_new.pdf
# Processing file: Dress Code Policy_new1.pdf
# Processing file: EnFuse - Code of Conduct_July24 CS (1)_new.pdf
# Processing file: EnFuse Social Media and Digital Communications Policy-V3_new.pdf
# Processing file: Equal Employment Opportunity Policy_new.pdf
# Processing file: Exit Process Flow (1)_new.pdf
# Processing file: Internal Job Posting_Internal Transfer Policy (1)_new.pdf
# Processing file: Leave Policy_Updated (1)_new1.pdf
# Processing file: Non-Discrimination and Anti-Harassment Policy_V3_new.pdf
# Processing file: Performance Appraisal and Development Policy_new.pdf
# Processing file: Prevention of Sexual Harassment (POSH) of Women at the Workplace Policy_V3_new.pdf

# %%
import re

def chunk_document_by_sections(document_text):
    """
    Split the document into sections based on numbering (e.g., 1., 2., etc.).
    Returns a list of chunks, where each chunk corresponds to a section.
    """
    # Regular expression to match section headers (e.g., "1.", "2.", etc.)
    section_pattern = re.compile(r'\n\s*\d+\.\s+')

    # Split the document into sections using the section pattern
    sections = re.split(section_pattern, document_text)

    # Remove any leading/trailing whitespace from each section
    sections = [section.strip() for section in sections if section.strip()]

    return sections

# Chunk the document into sections
chunks = chunk_document_by_sections(document)

chunks
# Out:
# ['Acceptable Use  \n \nPolicy Document',
#  'Overview  \n \nThe Company provides access to the vast information resources of the Internet to help its \nemployees execute business functions efficiently, and be a well -informed business citizen. \nThe facilities to provide that access represent a considerable commitment o f company \nresources for telecommunications, networking, software and storage. This acceptable use \npolicy sets the Company’s expectations for the use of all such resources.   \nWhile we’ve set forth explicit requirements for Company assets and Internet usage below, \nwe’d like to start by describing our Internet usage philosophy. First and foremost, the Internet \nis a business tool for the Company provided to you at significant cost. That means we expect \nyou to use Company assets and Internet resources primarily for business -related purposes,  \ni.e., to communicate with clients and suppliers, to research relevant topics and obtain useful \nbusiness information. We insist that you conduct yourself honestly and appropriately on the \nInternet, and respect the copyrights, software licensing rules, intel lectual property rights, \nprivacy and prerogatives of others, just as you would in any other business dealings. Further, \nall other Company policies apply to your conduct on the Internet, especially (but not \nexclusively) those that deal with intellectual pro perty protection, privacy, misuse of company \nresources, sexual harassment, information and data security, and confidentiality, integrity \nand availability of information.  \nThis policy applies to every individual who uses Company information assets and it sets out \nwhat the Company considers to be the acceptable use of those assets.',
#  'Internet Acceptable Use Policy  \nCompany user IDs and e -mail accounts must only be used for conducting Company’s \nbusiness functions.  \nThe use of Company computing resources is subject to local jurisdictional law and any abuse \nshall be dealt with accordingly.  \nUsers (Employees & Contractors) shall not visit Internet sites that contain obscene, hateful or \nother objectionable material, shall not attempt to bypass Company content control \ntechnology where it is installed and shall not make or post indecent remarks, comments, \nproposals or materials on the Internet.  \nThe display of any kind of sexually explicit image or document on any company system is a \nviolation of our code of conduct policy. In addition, sexually explicit material may not be \narchived, stored, distributed, edited or recorded using our network or com puting resources.  \n All users using the Internet facilities of the Company shall identify himself or herself honestly, \naccurately and completely (including one’s Company affiliation and function where \nrequested) when participating in any internet related activity, or when setting up accounts \non outside computer systems.  \nUsers shall not upload, download, or otherwise transmit commercial software or any \ncopyrighted materials belonging to the company or any third parties, and shall not reveal or \npublicize confidential information.  \nUsers may not download software from the Internet or execute or accept any software \nprograms or other code on the Internet unless it has first been approved by IT support \nservices in accordance with the Company policies and procedures.  \nAny software or files downloaded via the Internet onto the Company resources shall become \nthe Company’s property. Any such files or software may be used only in ways that are \nconsistent with their licenses or copyrights.  \nNo user may use the Company’s Internet facilities to deliberately propagate any virus, worm, \nTrojan horse, or trap -door program codes.  \nThe Company leadership shall authorize an individual who are authorized to speak to the \nmedia, to analysts or in public gatherings on behalf of the Company.  \nOnly those employees/officials who are duly authorized to speak to the media, to analysts or \nin public gatherings on behalf of the Company shall speak or write in the name of the \nCompany to any social media, newsgroup or chat rooms. An authorized individua l \nparticipant must refrain from any unauthorized political advocacy and must refrain from the \nunauthorized endorsement or appearance of endorsement by the Company of any \ncommercial product or service not sold or serviced by the Company. Other staff may \nparticipate in social media, newsgroups or chats in the course of business when relevant to \ntheir duties, but they do so as individuals speaking only for themselves.  \nThe Company retains the ownership rights to any authorized material posted to any social \nmedia, forum, newsgroup, chat or web page by any user in the course of his or her duties.  \n    \n  Users are reminded that where access is granted, social media, chats and newsgroups are \npublic forums where it is inappropriate to reveal confidential Company information, client \ndata, trade secrets, and any other material covered by existing Company policies and \nprocedures. Any violations by user(s) shall be dealt with according to our Code of Conduct \nor other disciplinary policies &/or procedures.  \nUsers will not carry out any other inappropriate activity as identified from time to time either in \nwriting or verbally by the Company and will not waste time or resources on non -Company \nbusiness. Although limited use of Company facilities for minor person al administrative tasks \nsuch as (for example) banking is permitted,  \nIt remains the responsibility of users with Internet access to take particular care to understand \nthe copyright, trademark, libel, slander and public speech control laws of all countries in  ...
#  'Email Usage Policy  \nCompany email shall only be used for the communication of official business information.  \nUsers are to protect their email ID access credentials and in no circumstances are allowed to \nshare with anybody including but not limited to other office colleagues, business associates \nor friends and family members etc..  \nCompany email facilities may not be used for sending defamatory emails, or using email for \nharassment, unauthorized corporate purchases, or for publishing views and opinions \n(defamatory or otherwise) about employees, contractors, suppliers, partners or cli ents of the \nCompany.  \nUsers shall not solicit emails that are unrelated to business activity or which are for personal \ngains, shall not send or receive any material which is obscene or defamatory or which is \nintended to annoy, harass, or intimidate another person, and shall not  present personal \nopinions as those of the company.  \nEmployees will have no privacy rights over emails sent&/or received using Company email.  \nOutgoing email attachments must be protected in line with their classification and due care \nmust be taken with regard to the recipients of such information.  \nUsers must not open incoming email attachments that originate with unknown third parties or \nthat, even if they appear to have been sent by a known party but not expected (however \nimportant that party may appear). These attachments may contain viruses, worm s or Trojans \nand any such emails must be deleted immediately, and on no account should they be \nforwarded, or copied on to anyone, whether inside or outside the network.  \nInternal group email addresses may not be given to external parties, unless approved by \nleadership or a designated approving authority based on business needs.  \nUsers are required to use their discretion to limit as far as practically possible the use of group \nemail addresses, to limit copying to unnecessary recipients, to restrict use of the “reply to all” \nfunction, and restrict the use of the blind copying feature.  \nEmployees are required to delete non -essential email messages as soon as possible and, on \na regular basis, to clear email boxes of correspondence that is no longer required.  \nEmail is a powerful tool for communication, but when overused or used inappropriately can \nbecome ineffective and a drain on the time of those receiving the emails. Judgement \nshould be used to ensure other forms of communication are used where email may not  be \nthe best method.',
#  'Compliance  \nUse of Internet / intranet / email / instant messaging may be subject to monitoring for reasons \nof security and / or network management and users may have their usage of these \nresources subjected to limitations by the Company.  \nThe distribution of any information through the Internet (including by e -mail, instant \nmessaging systems and any other computer -based systems) may be scrutinized by the \nCompany and the Company reserves the right to determine the suitability of the informat ion.  \nWe reserve the right for authorized users to inspect any and all files stored in private areas of \nour network, in shared folders, on Company assets in order to assure compliance with \npolicy.  \nThe Company may use independently -supplied software and data to identify inappropriate \nor sexually -explicit Internet sites. We may block access from within our networks to any sites \nthat we deem unacceptable. If you find yourself connected accidentally to a site that \ncontains sexually explicit or offensive material, you must disconnect from that site \nimmediately, regardless of whether that site had been previously deemed acceptable by \nany screening or rating program.  \nUsers shall not use the Company’s Internet facilities knowingly to disable or overload any \ncomputer system or network inside or outside the Company network.  \nIt is prohibited to circumvent any system intended to protect the privacy or security of the \nsystem, another user, or Company information.  \nThe Company reserves the right under this policy to limit Internet access to a user or a group \nof users.  \nBreaches of the requirements in this policy may be dealt with under the Company’s code of \nconduct and disciplinary procedures.']

# %%
import re

def chunk_documents_by_sections(documents_text):
    """
    Split each document in the list into sections based on numbering (e.g., 1., 2., etc.).
    Returns a list of lists, where each inner list corresponds to the sections of a document.
    """
    # Regular expression to match section headers (e.g., "1.", "2.", etc.)
    section_pattern = re.compile(r'\n\s*\d+\.\s+')

    # Initialize an empty list to hold the chunks for each document
    all_chunks = []

    # Iterate over the list of document texts
    for document_text in documents_text:
        # Split the document into sections using the section pattern
        sections = re.split(section_pattern, document_text)

        # Remove any leading/trailing whitespace from each section
        sections = [section.strip() for section in sections if section.strip()]

        # Append the chunks (sections) for the current document to the all_chunks list
        all_chunks.append(sections)

    return all_chunks


# Chunk the documents into sections
all_chunks = chunk_documents_by_sections(texts)

# Print the chunks for each document
for i, chunks in enumerate(all_chunks, start=1):
    print(f"Document {i}:")
    for j, chunk in enumerate(chunks, start=1):
        print(f"  Chunk {j}:\n{chunk}\n{'-'*40}")
# Out:
# Document 1:
#   Chunk 1:
# Acceptable Use
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Overview
#
# The Company provides access to the vast information resources of the Internet to help its
# employees execute business functions efficiently, and be a well -informed business citizen.
# The facilities to provide that access represent a considerable commitment o f company
# resources for telecommunications, networking, software and storage. This acceptable use
# policy sets the Company’s expectations for the use of all such resources.
# While we’ve set forth explicit requirements for Company assets and Internet usage below,
# we’d like to start by describing our Internet usage philosophy. First and foremost, the Internet
# is a business tool for the Company provided to you at significant cost. That means we expect
# you to use Company assets and Internet resources primarily for business -related purposes,
# i.e., to communicate with clients and suppliers, to research relevant topics and obtain useful
# business information. We insist that you conduct yourself honestly and appropriately on the
# Internet, and respect the copyrights, software licensing rules, intel lectual property rights,
# privacy and prerogatives of others, just as you would in any other business dealings. Further,
# all other Company policies apply to your conduct on the Internet, especially (but not
# exclusively) those that deal with intellectual pro perty protection, privacy, misuse of company
# resources, sexual harassment, information and data security, and confidentiality, integrity
# and availability of information.
# This policy applies to every individual who uses Company information assets and it sets out
# what the Company considers to be the acceptable use of those assets.
# ----------------------------------------
#   Chunk 3:
# Internet Acceptable Use Policy
# Company user IDs and e -mail accounts must only be used for conducting Company’s
# business functions.
# The use of Company computing resources is subject to local jurisdictional law and any abuse
# shall be dealt with accordingly.
# Users (Employees & Contractors) shall not visit Internet sites that contain obscene, hateful or
# other objectionable material, shall not attempt to bypass Company content control
# technology where it is installed and shall not make or post indecent remarks, comments,
# proposals or materials on the Internet.
# The display of any kind of sexually explicit image or document on any company system is a
# violation of our code of conduct policy. In addition, sexually explicit material may not be
# archived, stored, distributed, edited or recorded using our network or com puting resources.
#  All users using the Internet facilities of the Company shall identify himself or herself honestly,
# accurately and completely (including one’s Company affiliation and function where
# requested) when participating in any internet related activity, or when setting up accounts
# on outside computer systems.
# Users shall not upload, download, or otherwise transmit commercial software or any
# copyrighted materials belonging to the company or any third parties, and shall not reveal or
# publicize confidential information.
# Users may not download software from the Internet or execute or accept any software
# programs or other code on the Internet unless it has first been approved by IT support
# services in accordance with the Company policies and procedures.
# Any software or files downloaded via the Internet onto the Company resources shall become
# the Company’s property. Any such files or software may be used only in ways that are
# consistent with their licenses or copyrights.
# No user may use the Company’s Internet facilities to deliberately propagate any virus, worm,
# Trojan horse, or trap -door program codes.
# The Company leadership shall authorize an individual who are authorized to speak to the
# media, to analysts or in public gatherings on behalf of the Company.
# Only those employees/officials who are duly authorized to speak to the media, to analysts or
# in public gatherings on behalf of the Company shall speak or write in the name of the
# Company to any social media, newsgroup or chat rooms. An authorized individua l
# participant must refrain from any unauthorized political advocacy and must refrain from the
# unauthorized endorsement or appearance of endorsement by the Company of any
# commercial product or service not sold or serviced by the Company. Other staff may
# participate in social media, newsgroups or chats in the course of business when relevant to
# their duties, but they do so as individuals speaking only for themselves.
# The Company retains the ownership rights to any authorized material posted to any social
# media, forum, newsgroup, chat or web page by any user in the course of his or her duties.
#
#   Users are reminded that where access is granted, social media, chats and newsgroups are
# public forums where it is inappropriate to reveal confidential Company information, client
# data, trade secrets, and any other material covered by existing Company policies and
# procedures. Any violations by user(s) shall be dealt with according to our Code of Conduct
# or other disciplinary policies &/or procedures.
# Users will not carry out any other inappropriate activity as identified from time to time either in
# writing or verbally by the Company and will not waste time or resources on non -Company
# business. Although limited use of Company facilities for minor person al administrative tasks
# such as (for example) banking is permitted,
# It remains the responsibility of users with Internet access to take particular care to understand
# the copyright, trademark, libel, slander and public speech control laws of all countries in
# which the Company maintains a business presence, so that our use o f the Internet does not
# inadvertently violate any laws which might be enforceable against us.
# Users with Internet access shall not use Company Internet facilities to download
# entertainment software or games, or to play games against opponents over the Internet or
# indulge into torrent downloading &/or uploading.
# ----------------------------------------
#   Chunk 4:
# Email Usage Policy
# Company email shall only be used for the communication of official business information.
# Users are to protect their email ID access credentials and in no circumstances are allowed to
# share with anybody including but not limited to other office colleagues, business associates
# or friends and family members etc..
# Company email facilities may not be used for sending defamatory emails, or using email for
# harassment, unauthorized corporate purchases, or for publishing views and opinions
# (defamatory or otherwise) about employees, contractors, suppliers, partners or cli ents of the
# Company.
# Users shall not solicit emails that are unrelated to business activity or which are for personal
# gains, shall not send or receive any material which is obscene or defamatory or which is
# intended to annoy, harass, or intimidate another person, and shall not  present personal
# opinions as those of the company.
# Employees will have no privacy rights over emails sent&/or received using Company email.
# Outgoing email attachments must be protected in line with their classification and due care
# must be taken with regard to the recipients of such information.
# Users must not open incoming email attachments that originate with unknown third parties or
# that, even if they appear to have been sent by a known party but not expected (however
# important that party may appear). These attachments may contain viruses, worm s or Trojans
# and any such emails must be deleted immediately, and on no account should they be
# forwarded, or copied on to anyone, whether inside or outside the network.
# Internal group email addresses may not be given to external parties, unless approved by
# leadership or a designated approving authority based on business needs.
# Users are required to use their discretion to limit as far as practically possible the use of group
# email addresses, to limit copying to unnecessary recipients, to restrict use of the “reply to all”
# function, and restrict the use of the blind copying feature.
# Employees are required to delete non -essential email messages as soon as possible and, on
# a regular basis, to clear email boxes of correspondence that is no longer required.
# Email is a powerful tool for communication, but when overused or used inappropriately can
# become ineffective and a drain on the time of those receiving the emails. Judgement
# should be used to ensure other forms of communication are used where email may not  be
# the best method.
# ----------------------------------------
#   Chunk 5:
# Compliance
# Use of Internet / intranet / email / instant messaging may be subject to monitoring for reasons
# of security and / or network management and users may have their usage of these
# resources subjected to limitations by the Company.
# The distribution of any information through the Internet (including by e -mail, instant
# messaging systems and any other computer -based systems) may be scrutinized by the
# Company and the Company reserves the right to determine the suitability of the informat ion.
# We reserve the right for authorized users to inspect any and all files stored in private areas of
# our network, in shared folders, on Company assets in order to assure compliance with
# policy.
# The Company may use independently -supplied software and data to identify inappropriate
# or sexually -explicit Internet sites. We may block access from within our networks to any sites
# that we deem unacceptable. If you find yourself connected accidentally to a site that
# contains sexually explicit or offensive material, you must disconnect from that site
# immediately, regardless of whether that site had been previously deemed acceptable by
# any screening or rating program.
# Users shall not use the Company’s Internet facilities knowingly to disable or overload any
# computer system or network inside or outside the Company network.
# It is prohibited to circumvent any system intended to protect the privacy or security of the
# system, another user, or Company information.
# The Company reserves the right under this policy to limit Internet access to a user or a group
# of users.
# Breaches of the requirements in this policy may be dealt with under the Company’s code of
# conduct and disciplinary procedures.
# ----------------------------------------
# Document 2:
#   Chunk 1:
# Attendance and Punctuality
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Policy Brief
# Timely and regular attendance is an expectation of performance for all EnFuse employees. To
# ensure adequate staffing, positive employee morale, and to meet expected productivity
# standards throughout the organization, employees will be held accountable for adhering to
# their work schedule. If an employee is unable to meet this expectation, he/she must obtain
# approval from their Manager in advance of any requested schedule changes. This approval
# includes requests to use appropriate accruals and late arrivals t o or early departures from
# work. Departments had the discretion to evaluate extraordinary circumstances of a tardy,
# absence, or failure to check -in or check -out and determine whether or not to count the
# incident as an occurrence. The HR team is available t o advise Managers regarding the
# evaluation of extenuating circumstances.
# ----------------------------------------
#   Chunk 3:
# Procedures
# 2.1.   Absent
# An employee is deemed absent when he/she is unavailable for work as assigned/scheduled
# and such time -off was not scheduled/approved in advance as required by the department
# notification procedure.
# 2.2.   Tardy
# An employee is deemed to be tardy when he/she:
# ▪ Fails to report for work at the assigned/scheduled work time. Managers may replace the
# tardy employee for the full shift in these instances.
# ▪ Leaves work before the end of assigned/scheduled work time without prior supervisory
# approval
# ▪ Takes an extended meal or break period without approval
# ▪ Arrives to work past his/her scheduled start time. They may be replaced for the full shift at
# the discretion of his/her Manager/Supervisor.
# 2.3.   Check In/Out on Zoho
# Employees are required to follow established guidelines for recording their actual hours
# worked. A missed check in/out is a violation of this policy and includes:
# ▪ Failure to check -in/out on their designated time check at the beginning and/or end of
# their assigned shift
# ▪ Failure to check -in/out on their designated time check for the meal break
# ▪ Failure to accurately and timely report time worked
# ▪ Checking in/out early (or late) of the assigned shift without prior approval
# ▪ To record attendance on ZOHO,  Login Zoho  ,In Overview section, click check in and
# check out to record attendance.
# ▪ If any employee failed to check in / check out on zoho, they can choose Regularisation
# .STEPS FOR REG ULARI ZATION : Login zoho, go to attendance, then choose regularization
# and fill the details.
# 2.4.   Departmental Notification Procedure
# Employees are expected to follow departmental notification procedures if they will be late for
# work, will not be at work, or are requesting planned time away from work. Employees must
# request in advance to their Manager and in accordance with the departmen tal procedure if
# they wish to arrive early or leave early from an assigned shift.
# At the time of notification/call, the employee must notify their Managers/Supervisors when an
# absence is due to a documented/approved leave of absence to ensure appropriate
# tracking of leave utilization and absenteeism.     An employee who fails to call in and report to work as scheduled for five consecutively
# scheduled workdays will be viewed as having abandoned their position and shall be treated
# as an absconding case following respective processes. The Manager should consu lt with
# Human Resources if this situation occurs.
#
# Incidents of not following the departmental notification procedures, including
#
# No-Call/No -Show, will be addressed in accordance with the Discipline Process Protocol.
# 2.5.   Discipline Process Protocol
# Managers/Supervisors should monitor their employees' attendance regularly and address
# unsatisfactory attendance in a timely and consistent manner. If Managers/Supervisors notice
# a pattern of unscheduled usage of accrued time off work, they should discuss t his concern
# with the employee.
# When an employee has been previously counseled under the Discipline/Code of Conduct
# Policy and/or the Information Security Awareness Policy, the totality of the circumstances will
# be assessed when determining further action. For situations involving suspen sion or
# termination of employment, the Managers/Supervisors should consult with Human Resources
# before implementing disciplinary action.
# Timely and regular attendance is a performance expectation for all EnFuse employees.
# Consequently, those employees who have exhibited unsatisfactory attendance, which
# resulted in disciplinary action (written or final) during the year, may have the behavior
# documented in their annual evaluation.
# 2.5.1.  Instances
# An instance is documented as an absence, tardy, or missed time check -in/out. While an
# absence refers to a single failure to be at work, an instance may cover consecutive absent
# days when an employee is out for the same reason.
# The following grid is designed to provide guidelines when addressing the total number of
# instances:
#
#
#
#
# Absence/Tardies/Missed Check -In/Out
# ----------------------------------------
#   Chunk 4:
# 2 Instances : The employee receives a verbal warning  .
# ----------------------------------------
#   Chunk 5:
# 4 Instances : The employee receives a written warning  .         Instances/Days      Discipline Step/Action
# Absence/Tardies/Missed
# Check -In/Out
# 2 Instances     Step 1: Verbal warning
#      4 Instances     Step 2: Written warning
#      6 Instances     Step 3: Final written warning/show cause
#      Beyond 6 Instances   Step 4: Termination
#      3 days     Step 1: Verbal warning
# Total # of Days Absent     5 days     Step 2: Written warning & absconding
# trigger
# Consecutive or Non -
# Consecutive
# 6 days     Step 3: Final written warning/show cause
# Does Not Apply to Tardy     Beyond 6 days     Step 4: Termination
# Day of No Call/No Show     1 Instance     Step 2: Written warning
#
# Confidential – Internal Use Only
# Page 3 of 6
#     2 Instance     Step 3: Final written warning/show cause
#     3 Instance     Step 4: Termination     3. 6 Instances : The employee receives a final written warning/show cause  .
# ----------------------------------------
#   Chunk 6:
# Beyond 6 Instances : The employee faces termination  .
# Total Number of Days Absent
# ----------------------------------------
#   Chunk 7:
# 3 Days : The employee receives a verbal warning  .
# ----------------------------------------
#   Chunk 8:
# 5 Days : The employee receives a written warning  and triggers a review for
# potential absconding .
# ----------------------------------------
#   Chunk 9:
# 6 Days : The employee receives a final written warning/show cause
# (Step 3).
# ----------------------------------------
#   Chunk 10:
# Beyond 6 Days : The employee faces termination  .
# Day of No Call/No Show
# ----------------------------------------
#   Chunk 11:
# 1 Instance : The employee receives a written warning  .
# ----------------------------------------
#   Chunk 12:
# 2 Instances : The employee receives a final written warning/show cause  .
# ----------------------------------------
#   Chunk 13:
# 3 Instances : The employee faces termination  .
#
#
# Note:  The total number of days an employee is unavailable for work as scheduled and the
# total number of instances are considered when applying discipline. For example, at Step 1
# the maximum number of days the employee is allowed to be unavailable for work before
# receiving a Verbal Coaching is 2, regardless of the number of occurrences.
#
# 2.5.2.  New Hire Probation Period
# An employee within his/her probation period who has two occurrences will receive a Written
# Warning. If the employee has greater than two occurrences within the probation period,
# employment may be terminated; should the probation period be extended, this ru le still
# applies.
# 2.5.3.  Holidays
# If an employee calls out of work the day before, the day of, or the day after a holiday, the
# manager will review the circumstances of the absence. Based on this review, the manager
# has the discretion to determine whether to count the incident as a regular occurrence or go
# directly to issuing a Written Warning for the holiday -related call out. If an employee is already
# on discipline, they can progress to the next level.     2.6.   Departmental Policies – Approval Process
# EnFuse Senior Managers may develop a departmental attendance/punctuality policy that
# meets the unique operational needs of the department. If the leadership determines that a
# departmental policy is needed, the department will follow its Senior Manager’s ap proval
# process to establish the policy, which requires final approval from the leadership.
# ----------------------------------------
# Document 3:
#   Chunk 1:
# Compensatory Off Policy
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Compensatory Off Policy
#
# 1.1.  Introduction
# The Compensatory Off Policy document aims to define EnFuse's approach to the concept of
# Compensatory policy. This document will act as a guideline, and it is expected that all the
# EnFusians abide by the same.
# 1.2.  Definition of Compensatory Off
# Also known as Comp Off, Compensatory Off is an optional way of providing leave to
# employees who work on a holiday or a week off. The Compensatory Off policy provides
# employees with leaves to be compensated by a holiday or a week off work. Any such
# approved  Holiday / Week off working would be marked as a compensatory off in the system.
# It can be availed during the eligibility period (provided all the eligibility / validity criteria are
# qualifying).
# 1.3.  Eligibility for Applying for Compensatory Off
# The Employees can only apply for Compensatory Off if they fulfill the following two criteria:
# ▪ The Employee should have worked for One Full Day - On account of a project
# requirement pre -approved by the respective Manager
# ▪ The Employee should be a Full -time resource
# 1.4.  Compensatory Off Process Flow
# Following process allows the employees to add a request for a compensatory off:
# Add Compensatory Request.
# ▪ Login to Zoho People Account
# ▪ Go to 'Leave Tracker' and click on 'Compensatory Request'
# ▪ Click on '+Add Request'
# – Fill in all the following details:
# – a. Employee Name
#   – b. Worked Date
# – c. Add Description in the box (write specifically about project you worked on)
# ▪ Click on 'Submit'
#
# Once the request is submitted, respective managers will give approval to the same.
# After the request is approved, it reflects in the Compensatory Off list, where you can review the
# count of compensatory offs.
# ▪ Go to 'Leave Tracker' and click on 'List View'
# The List View will appear, and one can see the approved and pending Compensatory offs.
# Availing Compensatory Off:
# ▪ Click on 'Compensatory Off' in List View
# ▪ Add the details asked:
# – Date
# – Reason for leave
# – And click on 'Submit'
# 1.5.  Validity of Compensatory Off
# Any approved Compensatory Off is valid for 365 days from the date of approval. Manager to
# approve the Comp Off within a week of the date of week off working / Holiday working.
# 1.6.  Exceptions Management
# Any exceptions to the Compensatory Off policy to be approved HR Lead.
#
#
#
# Confidential – Internal Use Only   Page 6 of 6
# ----------------------------------------
# Document 4:
#   Chunk 1:
# Confirmation Policy
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Confirmation Policy
# 1.1.  Introduction
# All the new joiners undergo the Probation period. The probationary period is the duration
# provided to the new hires to get oriented with the organization, work, and culture. Also, the
# probation confirmation process helps analyze the new hire's performance during the
# probation period, analyze their qualities, identify the gap, and conclude whether the
# employee should be confirmed in the role or if the employee requires any training or is a
# misfit.
# 1.2.  Scope
# This policy applies to all new hire employees in the organization. This policy applies to full -time
# permanent employees. This policy does not apply to consultants or contractual employees.
# 1.3.  Objective
# To define a detailed procedure for reviewing the probation period and thereafter
# confirmation of employment in the organization.
# 1.4.  Process
# The standard probation duration lasts three months from the date of joining.
# The confirmation process initiates ten days before the actual confirmation due date.
# ▪ The Manager should maintain employee assessment / feedback
# ▪ In case the employee clears the probation successfully, the Manager can share the
# feedback with HR as a response to the probation alert email
# ▪ HR then confirms the employee in the system and shares the confirmation letter
# ▪ In case the employee requires more time to clear the probation successfully, the
# probation period gets extended, and the employee undergoes a Performance
# Improvement Plan (PIP) for a month. Manager to notify HR of such extensions and HR to
# share the PIP te mplate form to be filled by the Manager. Employee to be apprised jointly
# along with HR and Manager. The employee gets confirmed post full filling the
# expectations from the PIP form. The employee gets terminated if the expectations from
# the PIP form are not  met.
#   1.5.  Leave Management
# The employee will not be entitled to paid leaves during the probation period. Leaves shall be
# credited to leave balance post successful completion of probation. The employee should
# consult the Reporting manager for required emergency leaves.
# 1.6.  Exception Management
# Any exceptions to be above policy shall be approved by the Leadership team, and the
# same shall be liaised by the Human Resources team.
# ----------------------------------------
# Document 5:
#   Chunk 1:
# Diversity and Inclusion
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Introduction
# 1.1.  Purpose
# At EnFuse we recognize the value and advantages of having a diversified workforce. EnFuse
# seeks to promote an inclusive culture where employees are encouraged to succeed to the
# best of their abilities. Diversity is about recognizing and valuing the contrib ution of employees
# from different backgrounds, with different capabilities, perspectives and experiences.
# EnFuse embraces all employee differences including age, gender, ethnicity, and cultural
# background, and recognizes the benefits that diversity brings to deliver value to our clients
# and the communities in which we operate.
# Our policy is to leverage diversity and practice inclusion to contribute to the achievement of
# EnFuse’s strategic objectives by:
# ▪ Driving business performance and increasing competitiveness
# ▪ Helping to establish EnFuse as an employer of choice
# ▪ Recruiting, engaging and retaining a diverse team of talented people at EnFuse
# ▪ Bringing to life EnFuse’s culture and core values
# ----------------------------------------
#   Chunk 3:
# Policy Statement/Inclusions
# Our Definition of Diversity and Inclusion
# Workplace diversity refers to the variety of differences amongst people in an organization. An
# organization is a collective representation of people coming with individual differences in
# thoughts, personality, unique capabilities and talent that they bring  to work. It is an
# understanding that each individual is unique, and a recognition of our individual differences,
# so that each and every one feels important, respected, included and engaged as we
# assimilate people with differences including but not limited  to nationality, geography,
# ethnicity, gender, sexual orientation, age, physical abilities, family status, religious beliefs,
# perspective, experience or other ideologies. While we strongly appreciate diversity in all
# forms, achieving gender parity is a pri ority for us.
# At EnFuse, we have created an environment that is inclusive of people from different
# backgrounds. It is important that our employees reflect and respect the diversity we see in
# the world around us.
# Our employees are trained in recognizing and overcoming unconscious bias at the
# workplace among fellow colleagues. This extends to their interaction with clients and
# understanding the needs of a broader client base. Our organization is a safe space for
# everybody, where a person is not judged or discriminated against based on their identity.
# Recruitment, Selection & Talent Development
# The success of any D&I initiative is crucially dependent upon recruitment and staffing
# strategy. At EnFuse, we ensure that D&I is integrated into recruitment, talent development,
# and retention. A conscious effort is made to attract applicants from differen t diversity
# dimension groups to achieve and maintain a workforce that shows diversity across levels and
# functions. Search firms are required to provide diverse candidates. Advertising is targeted to
# diverse communities, diversity on interviewing panels is standard, and staffing/hiring
# managers are educated on the impact of bias. High potential talent from backgrounds not
# represented in a balanced way across the organization is provided with coaching,
# mentoring, and sponsorship opportunities.
# Objectives and Scope of the Diversity Policy
# We are committed to recruiting, retaining and promoting highly talented individuals to further
# the Organization’s strategic goals. This includes:
# ▪ Employing best practices in regards to D&I initiatives, benchmarked with reputed
# companies and institutes;
# ▪ Providing an environment of equality and respect for all employees;
# ▪ Not discriminating against any individuals on the basis of their gender, age, disability,
# ethnicity,sexual orientation, family status, religious beliefs and abilities;
# ▪ Ensuring fairness and avoiding unlawful discrimination in matters including
# remuneration,employment terms and conditions, promotions, training and development
#   opportunities; Promptly and fairly dealing with complaints of harassment, bullying, or
# unlawful discrimination by employees/clients
#
# ▪ Reviewing the employment policies and practices to promote fairness and address
# gender bias and underlying barriers to achieving gender balance;
# ▪ Building leadership capability by providing equal opportunities for training and
# development of staff, as required, to harness their full potential; and
# ▪ Providing equal opportunities for all employees in respect of career progression.
# We realize that achieving and sustaining an environment on founding D&I principles will need
# a balanced and concerted effort across the Organization.
# Policies on Workplace Conduct, Benefits, Work Life and Flexibility
# Our workplace policies  play an important role in reinforcing a culture on founding principles
# of diversity and inclusion. Policies have a strong underpinning on the way we work and
# approach our lives. These policies ensure that we adhere to highest standards of
# professionalism and conduct at workplace and work -life balance. Some of our policies are: -
# Equal Employment Opportunity Policy:  To achieve our business objectives, we are committed
# to a meritbased appointment process. We have policies and practices in place that enable
# capable and diverse employees access to all opportunities available with the organization,
# in a fair and equitabl e manner.We have the best in class tools and practices to ensure that
# we can access the broadest pool of diverse candidates, in keeping with our commitment to
# merit based employment.
# Code of Conduct Policy:  Commitment to eliminating all forms of unlawful discrimination,
# harassment, bullying and victimization of persons at workplace. Our Code of Conduct policy
# supports our commitment to maintain a workplace where all employees can work without
# fear of unaccep table workplace conduct impacting them. Every year employees have to
# give a personal undertaking in terms of having read and comply with the Code of Conduct
# policy.
# Leave Policies:  We at EnFuse believe that our people have changing needs during different
# life and career stages. A range of leave options are available to employees to help them
# manage those changes.
#  Document Title: Diversity and Inclusion
#   Template Version: V1
# Last Updated: March 2021
# ----------------------------------------
# Document 6:
#   Chunk 1:
# Dress Code
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Introduction
# EnFuse dress code policy is designed to help us all provide a consistent professional
# appearance to our customers and colleagues. Our appearance reflects on ourselves and
# the company. The goal is to be sure that we maintain a positive appearance and not to
# offend customers, clients, or colleagues.
# ----------------------------------------
#   Chunk 3:
# Scope
#
# This policy applies to all our employees (WFO)
# ----------------------------------------
#   Chunk 4:
# EnFuse Dress Code Policy
#
# ▪ Employees are expected to dress in [casual, business casual, smart casual, business] attire
# unless the day’s tasks require otherwise
# ▪ Employees must always present a clean, professional appearance. Everyone is expected
# to be well -groomed and wear clean clothing, free of holes, tears, or other signs of wear.
# ▪ Clothing with offensive or inappropriate designs or stamps are not allowed
# ▪ Clothing should be decent and not be revealing
# ▪ Clothing and grooming styles dictated by religion or ethnicity are exempt
#
# For M ales Allowed clothe s/attire  are:
# Formal  / casual shirts, T -Shirts, Jeans, Trrouser s.
#
# For Females Allowed clothe s/attire  are:
# Knee-length dresses/skirts, Sleeveless Tops, Trousers, Formals, Saree, T -shirt , Jeans, Salwar suit
#
# For Females Not Allowed clothe s/attire  are:
# Crop tops, Tank tops, Spaghetti tops, Tube tops, Halter neck, Off –shoulders, Above knee length
# dresses/skirts, torn jeans/clothing, Capri/ shorts/ 3/4th pants, beach wear
#  For Males Not Allowed clothe s/attire  are:
# Sleeveless, torn jeans/clothing, half -pants, beach wear
# ----------------------------------------
#   Chunk 5:
# Dress Code Violations
#
#
# Managers or supervisor are expected to inform employees when they are violating the dress
#
# code. Employees in violation are expected to immediately correct the issue. This may include
# having to leave work to change clothes and resume. Any such instance needs to be
# highlighted to HR.
# Repeated violations or violations that have major repercussions may result in disciplinary
# action being taken up to and including termination.
# ----------------------------------------
# Document 7:
#   Chunk 1:
# Code of Conduct
#
# Policy Document
# ----------------------------------------
#   Chunk 2:
# Message from the Co -Founder & Director
#
# Our commitment to ethical behavior and the solid ethical foundations are one of the most
# essential components of EnFuse Solutions Ltd. operation. We are committed to doing
# business the right way, based on a culture of ethics and compliance.
# In the long term, we can successfully face the challenges of a competitive market
# environment by accepting the imperatives of moral responsibility, both as individuals and as
# a company. In performing the job duties, the employees should always act lawfully , ethically
# and in the best interests of the EnFuse Solutions Ltd.
# Thank you for upholding our values and helping us do things right. It does not only mean that
# we provide well made, fairly priced and of exceptional quality products and services, but it
# also means that ethics and integrity is always born in mind. We sourc e material only from
# suppliers who have impeccable human rights and compliance records, and we ensure that
# our supply chain is of high integrity, and we monitor our entire operation for compliance with
# our Code.
#
# Kamran Shaikh and Imran Ansari
# Co-Founder & Director
# ----------------------------------------
#   Chunk 3:
# Introduction
#
# This Code of Ethics and Business Conduct  of EnFuse Solutions Ltd. (EnFuse, The Company)
# serves as our ethical commitment and as a guide to proper business conduct for all of our
# stakeholders. We, at EnFuse Solutions Ltd. are committed to doing business legally, ethically
# and in a transparent manner.
# This document applies to all staff who work for EnFuse (including officers, directors, managers,
# team leaders, employees, temporary, agency, interim, sub -contractor or consultant staff), and
# also includes other organizations who do business with us.
# EnFuse expects its staff to be impartial and honest in all affairs relating to their job. All staff
# bear a responsibility in general, to be of good faith and do nothing to destroy the trust
# necessary for employment.
# The success of our business is based on the trust we earn from our employees, customers, and
# shareholders. We gain credibility by adhering to our commitment to fairness and reaching
# our goals solely through ethical conduct. All staff are expected to adhere  to this Code in their
# professional, as well as personal conduct, treat everyone with respect, honesty, and fairness.
# EnFuse is open to any questions at any time and will not allow punishment or retaliation
# against anyone for reporting a misconduct in good faith.
# Managers and leaders have higher responsibility for demonstrating, also through their actions,
# the importance of this Code. Managers and leaders are responsible for promptly addressing
# every raised ethical question or concern. Employees must cooperate in i nvestigations of
# potential or alleged misconduct.
# Non-compliance to this Code is considered as misconduct that could warrant disciplinary
# action, including termination of employment or other contract in deserving cases.
# We are committed to making efforts to apply our values and norms also throughout the entire
# value chain of our own suppliers, sub -contractors, service providers and business partners.
# ----------------------------------------
#   Chunk 4:
# Ethical Principles of EnFuse
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set
# of core values that form the foundation of our business conduct. These principles reflect who
# we are as an organization and shape our interactions with clients, co lleagues, and the
# broader community.
# ----------------------------------------
#   Chunk 5:
# Honesty:
# – Employees should provide accurate and truthful information in all business
# interactions
# – Avoid deceptive practices, including misleading advertising, and be transparent in
# communications
# ----------------------------------------
#   Chunk 6:
# Integrity:
# – Act ethically and uphold high moral principles in all business activities –  Avoid
# conflicts of interest and disclose any potential conflicts that may arise
# ----------------------------------------
#   Chunk 7:
# Trustworthiness:
# – Build trust with clients, customers, and colleagues by consistently delivering on
# promises and commitments
# – Safeguard confidential information and respect privacy
# ----------------------------------------
#   Chunk 8:
# Respect for Others:
# – Treat all individuals with dignity and respect, regardless of differences such as race,
# gender, ethnicity, or background
# – Foster an inclusive and diverse work environment that values different perspectives
# ----------------------------------------
#   Chunk 9:
# Responsibility:
# – Take ownership of one's actions and decisions
# – Consider the impact of decisions on stakeholders, including employees, customers,
# and the community
# ----------------------------------------
#   Chunk 10:
# Accountability:
# – Hold oneself accountable for personal and professional behavior
# – Admit mistakes, learn from them, and take corrective actions when necessary
# ----------------------------------------
#   Chunk 11:
# Reliability:
# – Consistently deliver quality products and services
# – Honor commitments and deadlines, and communicate proactively if challenges arise
# ----------------------------------------
#   Chunk 12:
# Obedience to the Law:
# – Conduct business in compliance with all applicable laws and regulations
#
#   – Foster a culture of legal and ethical behavior and report any illegal activities promptly
# ----------------------------------------
#   Chunk 13:
# Professional Development:
# – Encourage continuous learning and development to enhance professional
# competence
# – Stay informed about industry standards and best practices
# ----------------------------------------
#   Chunk 14:
# Environmental and Social Responsibility:
# – Promote environmentally sustainable practices
# – Contribute positively to the communities in which the business operates
# ----------------------------------------
#   Chunk 15:
# Conflict Resolution:
# – Encourage open communication to resolve conflicts in a constructive and respectful
# manner
# – Seek mediation or other appropriate channels when conflicts arise
# ----------------------------------------
#   Chunk 16:
# Whistleblower Protection:
# – Provide protection and support for employees who report unethical behavior or
# violations of the Code of Ethics
# – Establish clear channels for reporting, investigation, and resolution of ethical concerns
# ----------------------------------------
#   Chunk 17:
# Ethical Decision Making
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set
# of core values that form the foundation of our business conduct. These principles reflect who
# we are as an organization and shape our interactions with clients, co lleagues, and the
# broader community.
# ----------------------------------------
#   Chunk 18:
# Legal Compliance:
# – Ensure that your actions are not only aligned with our values but also comply with all
# relevant laws and regulations
# ----------------------------------------
#   Chunk 19:
# Alignment with Company Values:
# – Uphold our company values and ethical principles in every decision and action,
# contributing to a workplace culture rooted in integrity
# ----------------------------------------
#   Chunk 20:
# Adherence to Code and Policies:
# – Follow our Code of Ethics and company policies diligently, providing a foundation for
# ethical behavior within the organization
# ----------------------------------------
#   Chunk 21:
# Respect for Others' Rights:
# – Always consider the rights and well -being of others in your actions, fostering a
# workplace characterized by respect and empathy
# ----------------------------------------
#   Chunk 22:
# Reputational Consideration:
# – Envision how your decisions would be perceived if they were to make headlines.
# Uphold our reputation by making choices that reflect positively on EnFuse
# ----------------------------------------
#   Chunk 23:
# Loyalty to Stakeholders:
# – Demonstrate loyalty to your colleagues, your family, and yourself by making decisions
# that prioritize long -term well -being over short -term gains
# ----------------------------------------
#   Chunk 24:
# The Right Thing to Do:
# – Embrace the question 'Is this the right thing to do?' as a guiding principle, ensuring
# that your actions align with your moral compass
# ----------------------------------------
#   Chunk 25:
# Resistance to Misrepresentation:
# – Stand firm in your commitment to integrity. If asked to misrepresent information or
# deviate from normal procedures, resist and uphold the values that define EnFuse.
# ----------------------------------------
#   Chunk 26:
# Compliance with Laws & Regulations
#
# Our commitment to integrity begins with complying with laws, rules and regulations. We
# understand and comply with the legal requirements and commercial practices of lawful
# business.
#
#   We are committed to adhere to every valid and binding contractual agreement that we
# conclude, and we do not abuse our rights.
# ▪ Companies Act, 2013 (India):  We being a public company ensure compliance with the
# Companies Act. This includes aspects like corporate governance, financial reporting,
# and meeting disclosure requirements. Our code of conduct could address ethical
# practices in these areas, such as prev enting insider trading and maintaining accurate
# financial records.
# ▪ SEBI (ICDR) Regulations, 2018:  As a company listed on the National Stock Exchange (NSE),
# EnFuse Solutions adheres to regulations set by the Securities and Exchange Board of India
# (SEBI). These regulations focus on protecting investor interests through transparent
# disclosures and fair market practices.
# ▪ Labor Laws:  Indian labor laws mandate fair wages, safe working conditions, and
# adherence to working hours. EnFuse Solutions' code reflects their commitment to these
# aspects.
# ▪ Data Privacy:  With our focus on data management and analytics, EnFuse Solutions has a
# robust data privacy policy aligned with Indian regulations. Our code emphasizes
# responsible data handling and user privacy protection.
# ▪ Intellectual Property:  The code might address respecting intellectual property rights of
# both EnFuse Solutions and their clients.
# A strong code of conduct policy that aligns with relevant laws and regulations demonstrates
# EnFuse Solutions' commitment to ethical business practices. This enables building trust with
# stakeholders and investors.
# Our staff must follow applicable laws and regulations, including the Code of Ethics and
# Business Conduct at all times and must ensure compliant operation.
# ----------------------------------------
#   Chunk 27:
# Human Rights
# We are committed to respect human dignity and rights of each individual and community
# whom we interact with during the course of work. We shall not, in any way, cause or
# contribute to the violation of human rights. Our staff shall treat everybody with dign ity,
# respect and care and uphold human rights.
# ----------------------------------------
#   Chunk 28:
# Fair Labour Practices & Working Conditions
#
# We are committed to promote equality in our employment practices and to fair employment
# and remuneration policy in compliance with applicable laws. We are firmly opposed to
# employing or contracting child or slave labour or any form of forced or compulsory or
# bonded labour. We condemn all forms of illegal, unfair, unethical labour practice that
# exploits workforce, destroys social security or serves as tax evasion, including but not limited
# to undeclared and “grey” work or holding back wages.
# Our staff shall act with integrity and treat their colleagues and others through the work with
# full respect.
# ----------------------------------------
#   Chunk 29:
# Discrimination & Harassment
# We provide equal opportunity in employment and we do not tolerate any discrimination or
# harassment or any type of abuse. No direct or indirect discrimination shall take place based
# on any professionally non -relevant trait or circumstance, like gender, mari tal status, age,
# national or social or ethnic origin, colour, religion and political opinion, disability, sexual
# orientation, employee representation, property, birth or other status. Any kind of
# discriminatory behaviour, harassment, bullying or victimizat ion is prohibited.
# All staff are expected to follow the highest standards of conduct in all verbal and written
# communication based on mutual respect, and must refrain from any form of harassment,
# slander or any behaviour that could be taken as offensive, intimidating, humili ating, malicious
# or insulting.
# ----------------------------------------
#   Chunk 30:
# Health, Safety & Environment
#
# We provide clean, safe and healthy work conditions and we are dedicated to maintaining a
# healthy environment. We are committed to minimise the impact on the natural environment
# of our operations. We make efforts to reduce the use of finite resources, like energy or water,
# and the harmful emissions, like waste.
# All staff must follow and comply with every relevant health, safety and environmental
# protection laws, regulations and rules all times.
# ----------------------------------------
#   Chunk 31:
# Fair Competition & Business Conduct
#
# Our relationships with business partners are built upon trust and mutual benefits compliant
# with competition law. We are dedicated to ethical and fair competition, as we sell services
# based on their quality, functionality and competitive pricing. We will m ake independent
# pricing and marketing decisions and will not improperly cooperate or coordinate our
# activities with our competitors. We will not offer or solicit improper payments or gratuities, nor
# will we engage or assist in unlawful boycotts of particul ar customers. We commit to comply
# with all applicable trade controls, restrictions, sanctions and import -export embargoes.
# We do not allow any violence of the fairness of any tendering process in any way. We refrain
# from damaging competition and the reputation of any business partners and any behaviour
# that harms competitor’s credibility.
# We do not hold back maliciously, unlawfully or unduly payments towards our partners, and
# we do not allow such practices in our supply chain, we fight the unethical practice of “debt
# chain”.
# ...
# minimum of once every month.
# 8.2.  Importance of One -to-One Discussions
# Regular one to one discussions feed into the annual performance appraisal cycle which
# helps to ensure that the meetings are meaningful based on ‘real’ issues.
# ▪ One to one discussions are vital in giving employees and Reporting managers an
# opportunity to discuss on -going development or concerns. It is recognised that at times
# of increased activity it is not always easy to conduct one to one’s. At busy times
# Reporting managers are encouraged to think creatively as to how they can conduct
# one to one’s with employees (for example team huddles, project / to -do lists, use of
# white boards).
# ▪ One to one discussions are essential in keeping employees talking and communicating
# with one another. They keep employees and Reporting managers ‘on task’ with
# objectives set and enhance the progression of development.
# ----------------------------------------
#   Chunk 30:
# Talent and Succession Planning
# 9.1.  Talent Management
# All employees should have the opportunity to develop to their full potential and to engage in
# career conversations to help mitigate any potential people risks that are identified through
# workforce planning. The Performance Appraisal conversation is the nat ural place for this to
# occur, and should focus on exploring career aspirations, interest in future roles and where
# development opportunities may exist and able to be incorporated into the Career
# progression/ development plan.
# 9.2.  Succession Planning
# It is vital that consideration is given during the Performance Appraisal conversation of the
# employee’s aspirations, and whether or not any development can take place to support
# succession and career planning.
# ----------------------------------------
#   Chunk 31:
# End of Year Assessment
# Each end of year assessment starts with a new set of goals under KRAs. The form (for initial
# completion by the employee), helps to set an agenda for the conversation with the
# Reporting manager. This process requires a formal meetings  every six months. April (set
# objectives), September (to review previous six months). The process also depends on regular
# one to one meetings to review progress.
# ----------------------------------------
#   Chunk 32:
# 360 - Feedback Evaluations – Manager Group
#
# All employees will be encouraged to participate in the 360 Degree Appraisal for the
# respective Reporting Managers. These will tend to take place during the last quarter(i.e.
# January to March). A list of participants would be identified at the start of the process. It
# must include the following as well:
# ▪ Reporting Manager
# ▪ Colleagues and Peers
# ▪ People who work for you (if applicable)
# ▪ External partner organizations (if applicable)
# The 360 -degree appraisal process will be coordinated by the HR Team. Participants will be
# given a period of a weeks’ time to complete the appraisals which will be collated into a
# report.
# ----------------------------------------
#   Chunk 33:
# Learning Requirements
# All Reporting managers are required to attend EnFuse ’s Performance Appraisal training
# conducted by HR Team/External vendor.
# ----------------------------------------
# Document 15:
#   Chunk 1:
# Prevention of Sexual Harassment
# (POSH) of Women at the Workplace
#
# Internal Policy Document
# ----------------------------------------
#   Chunk 2:
# Introduction
# India’s first legislation explicitly addressing the issue of workplace sexual harassment, the
# Sexual Harassment of Women at Workplace (Prevention, Prohibition and Redressal) Act, 2013
# (“POSH Act” ), was enacted by the Ministry of Women and Child Development, India in 2013.
# The POSH Act was enacted to prevent and protect women from workplace sexual
#
#   harassment, as well as to ensure effective redressal of sexual harassment complaints. The
# POSH Act is not gender -neutral legislation; it protects against sexual harassment of women at
# work, as well as the prevention and redressal of sexual harassment complaints and related
# matters. As a result, the POSH Act protections do not apply to 'men' vic tims.
# EnFuse Solutions Pvt. Ltd. is committed to providing equal opportunity and a harassment -free
# workplace. for all employees, regardless of race, caste, religion, color, ancestry, marital
# status, gender, sexual orientation, age, nationality, ethnic origin, or  disability. To create such
# a safe and conducive work environment, this Policy has been framed in accordance with
# the provisions of India's "Sexual Harassment of Women at Workplace (Prevention, Prohibition,
# and Redressal) Act, 2013" and existing rules fram ed thereunder, namely the "Sexual
# Harassment of Women at Workplace (Prevention, Prohibition, and Redressal) Rules, 2013.
# The Company also believes that all its employees have a right to be treated with dignity.
# Sexual harassment at work or elsewhere involving an employee or employees is a grave
# offense and is, therefore, punishable.
# ----------------------------------------
#   Chunk 3:
# Purpose and Scope
# This policy aims to protect women from sexual harassment at work, along with the prevention
# and redressal of complaints of sexual harassment and related matters.
# This policy extends to all categories of employees working at EnFuse Solutions Ltd., including
# full-time and contractual employees, office staff, people hired on daily wage basis, or
#
#   individuals coming to the workplace for any purpose, but not limited to visitors, vendors,
# contractual resources and applies to any alleged act of harassment against employees at
# our workplace, whether the incident has occurred during of beyond office hours.
# Harassment will not be tolerated if engaged in by clients or by suppliers or any other business
# associates.
# ----------------------------------------
#   Chunk 4:
# Objective
# The objective of the POSH policy is to create a safe, secure, and respectful work environment
# for all women employees. This policy outlines acceptable behavior and procedures for
# reporting incidents of harassment so that everyone in the workplace understan ds the
# appropriate standards and expectations. Additionally, this policy serves to protect women
# employees from harassment by coworkers or third parties such as clients, vendors, or
# customers. The goal of our policy is to ensure that complaints are taken s eriously, and that
# prompt action is taken against any activity that may be considered harassing or
# discriminatory towards any women employee regardless of race, gender, age, sexual
# orientation, etc. By providing a zero -tolerance approach to harassment in t he workplace we
# hope to create an understanding amongst all members of our team that discrimination will
# not be tolerated, and swift disciplinary actions will follow if needed.
# ----------------------------------------
#   Chunk 5:
# What Amounts to Sexual Harassment?
#
# Sexual harassment can include unwanted sexual advances, requests for sexual favors, and
# other sexually motivated verbal, visual, or physical behavior. It can refer to behavior by either
# gender toward another person of the same or opposite gender.
# Sexual harassment can occur between coworkers as well as when a person uses sexual
# behavior to control, influence, or affect another person's career, salary, or job. It may also
# occur between an employee and someone with whom the employee interacts during his or
# her work who is not employed by the Company.
# "Sexual Harassment" includes, but is not limited to, any one or more of the following
# unwanted acts or behavior (whether directly or indirectly):
# ----------------------------------------
#   Chunk 6:
# Any unwelcome sexually determined behavior, or pattern of conduct, that would cause
# discomfort and / or humiliate a person at whom the behavior or conduct was directed,
# namely:
# a. Unwelcome sexual advances, whether verbal, nonverbal, or physical, whether
# implicit or explicit
# b. Touching, stalking, sounds with explicit and / or implicit sexual connotation/overtones,
# and molestation are all examples of physical contact and advances.
# c. Teasing, voyeurism, innuendos, and taunts with an implicit sexual connotation,
# physical confinement and / or unwanted touching
# d. Request or demand for sexual favors
# e. Sexually -colored remarks or sexual remarks about a person's clothing or body
# f. Display of pictures, signs, etc., with sexual connotation / overtones in the workplace
# and work -related areas
# g. Making or posting indecent / vulgar / sexual pranks, teasing, jokes, demeaning or
# offensive pictures, cartoons, pornography, or other materials via email, SMS, MMS,
# memes, gestures, etc.
# h. Repeatedly requesting to socialize during off -duty hours or expressing sexual interest
# against a person's wishes
# i. Giving or leaving sexually suggestive gifts or objects
# j. Eve teasing, innuendos, taunts, forced physical confinement, or any other act likely to
# infringe on one's privacy
# k. Persistently watching, following, or contacting a person
# l. Any other unwanted physical, verbal or non -verbal conduct of sexual nature
# ----------------------------------------
#   Chunk 7:
# Sexual harassment occurs when any of the following circumstances occur or are present
# in relation to any sexually determined act or behaviour:
# a. Implied or explicit promise of preferential treatment in employment;
# b. Implied or explicit threat of detrimental treatment in employment;
# c. Implied or explicit threat about the present or future employment status
# d. Interfering with the person’s work or creating an intimidating, offensive, or hostile work
# environment
#   e. Humiliating treatment likely to affect the health or safety of the aggrieved
# This policy applies to an alleged act of sexual harassment committed during or after office
# hours. Furthermore, whether or not harassment occurred is determined by the experience of
# the aggrieved woman, not by the intent of the people.
# ----------------------------------------
#   Chunk 8:
# The Internal Complaints Committee (ICC)
#
# To prevent instances of sexual harassment and to receive and effectively deal with
# complaints pertaining to the same, the Internal Complaints Committee (IC) has been
# appointed for all administrative units / offices of the company.
# This committee comprises of
# ----------------------------------------
#   Chunk 9:
# Presiding Officer – Kamran Shaikh
# ----------------------------------------
#   Chunk 10:
# Committee
# a. Reema Thakur
# b. Vedha Hiremath
# c. Anuja Gaikwad
# d. Parthiv Bhaskar
# e. Sunil Saundalkar
#
# The committee will be responsible for:
# ▪ Receiving complaints of sexual harassment at the workplace
# ▪ Initiating and conducting inquiry as per the established procedure
# ▪ Submitting findings and recommendations of inquiries
# ▪ Coordinating with the employer in implementing appropriate action
# ▪ Maintaining strict confidentiality throughout the process as per established guidelines
# ----------------------------------------
#   Chunk 11:
# Systems for Reporting
# To ensure a workplace free of discrimination and harassment, the Company has established
# a formal procedure for handling complaints of discrimination or harassment. We strongly
# encourage employees to file a formal complaint as soon as possible. He or she s hould not
# wait until harassment becomes severe and pervasive before reporting it. In case one is being
# harassed, whether by a colleague, customer, or vendor, the harassed one(victim) can
# choose to talk to any of these people:
# ▪ Offenders – In case the suspect is that an offender doesn’t realize they are guilty of
# harassment, harassed one(victim) could talk to them directly in an effort to resolve the
# issue. This approach is appropriate for cases of minor harassment (e.g. inappropriate
# jokes between colleagues.) Avoid using this approach with customers or stakeholde rs.
# ▪ Respective Manager  – If customers, stakeholders, or team members are involved in the
# claim, harassed one(victim) may reach out to the Respective Manager. Respective
# Manager to assess the situation and to contact HR to report the same.
# ▪ HR -- Harassed one(victim) to feel free to reach out to HR in any case of harassment no
# matter how minor it may seem. For their safety, contacting HR as soon as possible in
# cases of serious harassment (e.g. sexual advances) or if the Respective Manager is
# involved in their claim. Anything the victim discloses shall remain confidential.
# ----------------------------------------
#   Chunk 12:
# Governance
# An employee who feels he / she has encountered or observed activity that violates this
# policy must report the incident promptly to his / her Manager, Human Resources, and / or the
# Internal Complaints Committee (ICC) under the Prevention of Sexual Harassment (POSH) of
# Women at the Workplace policy of the Company. This policy authorizes these people to
# accept complaints on behalf of the Company.
# We have set up various mechanisms to identify early business and / or personal misconduct
# relating to harassment, including:
# ----------------------------------------
#   Chunk 13:
# Having available to all employees the:
# a. Ethics at Workplace Policy
# b. Code of Conduct policy
# c. Non-Discrimination and Anti -Harassment Policy
# ----------------------------------------
#   Chunk 14:
# Delivering appropriate training, which includes ethics, unconscious bias, and compliance
# training
# ----------------------------------------
#   Chunk 15:
# Process for Lodging a Complaint
# If you believe that you have been the target of discrimination or harassment, the Company
# encourages you to report the incident(s) in question soon after the incident occurs as
# possible to Human Resources, or your manager, or the ICC. If the person accused  of
# discrimination or harassment is from HR, you may submit your complaint to another manager
# or the ICC to handle the complaint.
# An aggrieved woman may make, in writing, a complaint of sexual harassment at workplace
# to the Internal Complaints Committee (ICC) within a period of 3 months from the date of
# incident / last incident.
# If the Aggrieved Woman is unable to make a complaint on account of her mental
# incapacity, a complaint may be filed by:
# a. her relative or friend; or
# b. a special educator; or
# c. a qualified psychiatrist or psychologist; or
# d. the guardian or authority under whose care she is receiving treatment or care; or
# e. any person who has knowledge of the incident jointly with the Aggrieved Woman’s
# relative or friend or a special educator or qualified psychiatrist or psychologist, or
# guardian or authority under whose care she is receiving treatment or care
# If the Aggrieved Woman for any other reason is unable to make a complaint, a complaint
# may be filed by any person who has knowledge of the incident, with her written consent.
# If the Aggrieved Woman is deceased, a complaint may be filed by any person who has
# knowledge of the incident, with the written consent of her legal heir.
# The complaint shall be submitted by the complainant to the IC in writing or shall be
# submitted to the IC electronically at ICC@enfuse -solutions.com . The complaint can also be
# physically submitted to any IC member.
# Anonymous or pseudonymous complaints will not be investigated.
# ----------------------------------------
#   Chunk 16:
# Corrective Measures
# We do not tolerate harassment or discrimination in violation of this policy. If an inquiry
# uncovers that a breach of this policy or other improper behavior has occurred, the
# Company will take remedial action, up to and including termination of employment, as
# necessary under the circumstances, regardless of the work status of those involved.
# ----------------------------------------
#   Chunk 17:
# Exception Management
# Any exceptions to be above policy shall be approved by the ICC, and the same shall be
# processed further by the Human Resources team.
# ----------------------------------------

# %% [markdown]
# # Router

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# %%
def rewrite_query_for_rag(query):
    # Load environment variables
    load_dotenv()

    # Configure the Generative AI API
    genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

    # Define the generation configuration
    generation_config = {
        'temperature': 0,
        'max_output_tokens': 8000,
        'top_p': 0.2
    }

    # Initialize the model
    model = genai.GenerativeModel(model_name='gemini-pro', generation_config=generation_config)

    # Define the prompt
    prompt = f"""
    Behave as a HR chatbot .If it is greeting ,make a reply to the {query}"
    """

    # Generate response
    response_jd = model.generate_content([prompt])

    # Extract and return the text
    return response_jd.parts[0].text

# %%
rewrite_query_for_rag("How are you")
# Out:
# "**If the input is a greeting:**\n\n**User:** Hello, how are you?\n\n**Chatbot:** Hello there! I'm doing well, thank you for asking. How can I assist you today?"

# %% [markdown]
# # Testing chunking

# %%
from PyPDF2 import PdfReader
def extract_text_from_pdf(pdf_path):
    """Extract text from a given PDF."""
    pdf_reader = PdfReader(pdf_path)
    text = ""
    for page in pdf_reader.pages:
        text += page.extract_text()
    return text

# %%
text = extract_text_from_pdf(r"D:\RAG\Data\EnFuse - Code of Conduct_July24 CS (1)_new1.pdf")
type(text)
# Out:
# str

# %%
def split_text_into_chunks(text, chunk_size=650, chunk_overlap=70):
    """Split text into smaller chunks without breaking sentences."""
    # Regular expression to match sentence boundaries (., ?, !, etc.)
    sentence_endings = re.compile(r'([.!?])\s+')

    # Split the text into sentences based on sentence-ending punctuation
    sentences = sentence_endings.split(text)

    # Reconstruct the sentences correctly
    sentences = [sentences[i] + sentences[i+1] for i in range(0, len(sentences)-1, 2)]

    # Add the last sentence if the text ended without punctuation at the end
    if len(sentences) * 2 != len(sentence_endings.findall(text)):
        sentences.append(sentences[-1] + sentences[-2])

    chunks = []
    current_chunk = ""

    for sentence in sentences:
        # Check if adding this sentence will exceed chunk_size
        if len(current_chunk) + len(sentence) + 1 > chunk_size:
            # If it exceeds, save the current chunk and start a new one
            chunks.append(current_chunk.strip())
            current_chunk = sentence
        else:
            # Otherwise, append the sentence to the current chunk
            if current_chunk:
                current_chunk += " " + sentence
            else:
                current_chunk = sentence

    # Add any remaining content as the last chunk
    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

# %%
import re
final = split_text_into_chunks(text, chunk_size=650, chunk_overlap=70)

# %%
for i in final:
    print(i)
    print("===============================")
# Out:
# Code of Conduct
#
# Policy Document
#
# 1. Message from the Co -Founder & Director
#
# Our commitment to ethical behavior and the solid ethical foundations are one of the most
# essential components of EnFuse Solutions Ltd. operation. We are committed to doing
# business the right way, based on a culture of ethics and compliance. In the long term, we can successfully face the challenges of a competitive market
# environment by accepting the imperatives of moral responsibility, both as individuals and as a
# company.
# ===============================
# In performing the job duties, the employees should always act lawfully , ethically
# and in the best interests of the EnFuse Solutions Ltd. Thank you for upholding our values and helping us do things right. It does not only mean that
# we provide well made, fairly priced and of exceptional quality products and services, but it
# also means that ethics and integrity is always born in mind. We sourc e material only from
# suppliers who have impeccable human rights and compliance records, and we ensure that
# our supply chain is of high integrity, and we monitor our entire operation for compliance with
# our Code.
# ===============================
# Co-Founder & Director :
#  Kamran Shaikh and Imran Ansari are the Co -Founder and Director. 2. Introduction
#
# This Code of Ethics and Business Conduct  of EnFuse Solutions Ltd. (EnFuse, The Company) serves
# as our ethical commitment and as a guide to proper business conduct for all of our
# stakeholders. We, at EnFuse Solutions Ltd. are committed to doing business legally, ethically
# and in a transparent mann er.
# ===============================
# This document applies to all staff who work for EnFuse (including officers, directors, managers,
# team leaders, employees, temporary, agency, interim, sub -contractor or consultant staff), and
# also includes other organizations who do business with us. EnFuse expects its staff to be impartial and honest in all affairs relating to their job. All staff
# bear a responsibility in general, to be of good faith and do nothing to destroy the trust
# necessary for employment. The success of our business is based on the trust we earn from our employees, customers, and
# shareholders.
# ===============================
# We gain credibility by adhering to our commitment to fairness and reaching our
# goals solely through ethical conduct. All staff are expected to adhere  to this Code in their
# professional, as well as personal conduct, treat everyone with respect, honesty, and fairness. EnFuse is open to any questions at any time and will not allow punishment or retaliation against
# anyone for reporting a misconduct in good faith. Managers and leaders have higher responsibility for demonstrating, also through their actions, the
# importance of this Code. Managers and leaders are responsible for promptly addressing every
# raised ethical question or concern.
# ===============================
# Employees must cooperate in i nvestigations of potential or
# alleged misconduct. Non-compliance to this Code is considered as misconduct that could warrant disciplinary action,
# including termination of employment or other contract in deserving cases. We are committed to making efforts to apply our values and norms also throughout the entire
# value chain of our own suppliers, sub -contractors, service providers and business partners. 3. Ethical Principles of EnFuse
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set of
# core values that form the foundation of our business conduct.
# ===============================
# These principles reflect who we
# are as an organization and shape our interactions with clients, co lleagues, and the broader
# community. 1. Honesty:
# – Employees should provide accurate and truthful information in all business interactions
# – Avoid deceptive practices, including misleading advertising, and be transparent in
# communications
# 2. Integrity:
# – Act ethically and uphold high moral principles in all business activities –    Avoid conflicts of
# interest and disclose any potential conflicts that may arise
# 3.
# ===============================
# Trustworthiness:
# – Build trust with clients, customers, and colleagues by consistently delivering on promises
# and commitments
# – Safeguard confidential information and respect privacy
# 4. Respect for Others:
# – Treat all individuals with dignity and respect, regardless of differences such as race,
# gender, ethnicity, or background
# – Foster an inclusive and diverse work environment that values different perspectives
# 5. Responsibility:
# – Take ownership of one's actions and decisions
# – Consider the impact of decisions on stakeholders, including employees, customers, and
# the community
# 6.
# ===============================
# Accountability:
# – Hold oneself accountable for personal and professional behavior
# – Admit mistakes, learn from them, and take corrective actions when necessary
# 7. Reliability:
# – Consistently deliver quality products and services
# – Honor commitments and deadlines, and communicate proactively if challenges arise
# 8. Obedience to the Law:
# – Conduct business in compliance with all applicable laws and regulations
# – Foster a culture of legal and ethical behavior and report any illegal activities promptly
#
#
# 9.
# ===============================
# Professional Development:
# – Encourage continuous learning and development to enhance professional competence
# – Stay informed about industry standards and best practices
# 10. Environmental and Social Responsibility:
# – Promote environmentally sustainable practices
# – Contribute positively to the communities in which the business operates
# 11. Conflict Resolution:
# – Encourage open communication to resolve conflicts in a constructive and respectful
# manner
# – Seek mediation or other appropriate channels when conflicts arise
# 12.
# ===============================
# Whistleblower Protection:
# – Provide protection and support for employees who report unethical behavior or violations
# of the Code of Ethics
# – Establish clear channels for reporting, investigation, and resolution of ethical concerns
#
#
# 4. Ethical Decision Making
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set
# of core values that form the foundation of our business conduct. These principles reflect who
# we are as an organization and shape our interactions with clients, co lleagues, and the broader
# community. 1.
# ===============================
# Legal Compliance:
# – Ensure that your actions are not only aligned with our values but also comply with all
# relevant laws and regulations    2. Alignment with Company Values:
# – Uphold our company values and ethical principles in every decision and action,
# contributing to a workplace culture rooted in integrity
# 3. Adherence to Code and Policies:
# – Follow our Code of Ethics and company policies diligently, providing a foundation for
# ethical behavior within the organization
# 4.
# ===============================
# Respect for Others' Rights:
# – Always consider the rights and well -being of others in your actions, fostering a workplace
# characterized by respect and empathy
# 5. Reputational Consideration:
# – Envision how your decisions would be perceived if they were to make headlines. Uphold
# our reputation by making choices that reflect positively on EnFuse
# 6. Loyalty to Stakeholders:
# – Demonstrate loyalty to your colleagues, your family, and yourself by making decisions
# that prioritize long -term well -being over short -term gains
# 7.
# ===============================
# The Right Thing to Do:
# – Embrace the question 'Is this the right thing to do?' as a guiding principle, ensuring that
# your actions align with your moral compass
# 8. Resistance to Misrepresentation:
# – Stand firm in your commitment to integrity. If asked to misrepresent information or
# deviate from normal procedures, resist and uphold the values that define EnFuse. 5. Compliance with Laws & Regulations
#
# Our commitment to integrity begins with complying with laws, rules and regulations. We
# understand and comply with the legal requirements and commercial practices of lawful business.
# ===============================
# We are committed to adhere to every valid and binding contractual agreement that we
#
# conclude, and we do not abuse our rights. ▪ Companies Act, 2013 (India):  We being a public company ensure compliance with the
# Companies Act. This includes aspects like corporate governance, financial reporting, and
# meeting disclosure requirements. Our code of conduct could address ethical practices in
# these areas, such as preve nting insider trading and maintaining accurate financial records.
# ===============================
# ▪ SEBI (ICDR) Regulations, 2018:  As a company listed on the National Stock Exchange (NSE),
# EnFuse Solutions adheres to regulations set by the Securities and Exchange Board of India
# (SEBI). These regulations focus on protecting investor interests through transparent
# disclosures and fair market practices. ▪ Labor Laws:  Indian labor laws mandate fair wages, safe working conditions, and adherence
# to working hours. EnFuse Solutions' code reflects their commitment to these aspects. ▪ Data Privacy:  With our focus on data management and analytics, EnFuse Solutions has a
# robust data privacy policy aligned with Indian regulations.
# ===============================
# Our code emphasizes
# responsible data handling and user privacy protection. ▪ Intellectual Property:  The code might address respecting intellectual property rights of both
# EnFuse Solutions and their clients. A strong code of conduct policy that aligns with relevant laws and regulations demonstrates
# EnFuse Solutions' commitment to ethical business practices. This enables building trust with
# stakeholders and investors. Our staff must follow applicable laws and regulations, including the Code of Ethics and
# Business Conduct at all times and must ensure compliant operation.
# ===============================
# Human Rights
# We are committed to respect human dignity and rights of each individual and community
# whom we interact with during the course of work. We shall not, in any way, cause or
#
# 6. contribute to the violation of human rights. Our staff shall treat everybody with dignity,
# respect and care and uphold human rights. 7. Fair Labour Practices & Working Conditions
#
# We are committed to promote equality in our employment practices and to fair employment
# and remuneration policy in compliance with applicable laws.
# ===============================
# We are firmly opposed to
# employing or contracting child or slave labour or any form of forced or compulsory or
# bonded labour. We condemn all forms of illegal, unfair, unethical labour practice that
# exploits workforce, destroys social security or serves as tax evasion, including but not limited
# to undeclared and “grey” work or holding back wages. Our staff shall act with integrity and treat their colleagues and others through the work with
# full respect. 8. Discrimination & Harassment
# We provide equal opportunity in employment and we do not tolerate any discrimination or
# harassment or any type of abuse.
# ===============================
# No direct or indirect discrimination shall take place based
# on any professionally non -relevant trait or circumstance, like gender, mari tal status, age,
# national or social or ethnic origin, colour, religion and political opinion, disability, sexual
# orientation, employee representation, property, birth or other status. Any kind of
# discriminatory behaviour, harassment, bullying or victimizat ion is prohibited.
# ===============================
# All staff are expected to follow the highest standards of conduct in all verbal and written
# communication based on mutual respect, and must refrain from any form of harassment,
# slander or any behaviour that could be taken as offensive, intimidating, humili ating,
# malicious or insulting. 9. Health, Safety & Environment
#
# We provide clean, safe and healthy work conditions and we are dedicated to maintaining a
# healthy environment. We are committed to minimise the impact on the natural environment
# of our operations. We make efforts to reduce the use of finite resources, like energy or water,
# and the harmful emissions, like waste.
# ===============================
# All staff must follow and comply with every relevant health, safety and environmental
# protection laws, regulations and rules all times. 10. Fair Competition & Business Conduct
#
# Our relationships with business partners are built upon trust and mutual benefits compliant
# with competition law. We are dedicated to ethical and fair competition, as we sell services
# based on their quality, functionality and competitive pricing. We will m ake independent
# pricing and marketing decisions and will not improperly cooperate or coordinate our
# activities with our competitors.
# ===============================
# We will not offer or solicit improper payments or gratuities, nor
# will we engage or assist in unlawful boycotts of particul ar customers. We commit to comply
# with all applicable trade controls, restrictions, sanctions and import -export embargoes. We do not allow any violence of the fairness of any tendering process in any way. We refrain
# from damaging competition and the reputation of any business partners and any behaviour
# that harms competitor’s credibility. 11.
# ===============================
# We do not hold back maliciously, unlawfully or unduly payments towards our partners, and
# we do not allow such practices in our supply chain, we fight the unethical practice of “debt
# chain”. 11. Our staff is responsible for ensuring fair business during their job and adhere to every
# competition, consumer protection and fair marketing rule. Customers and business partners
# shall be treated fairly and equally, products and services shall be displayed  in a manner that
#
#
# is fair and accurate (fair marketing and advertising), and that discloses all relevant
# information. 11.
# ===============================
# Anti-corruption
#
# We firmly condemn and do not tolerate all forms of corruption. It is prohibited directly or
# indirectly offering, promising, giving, asking, soliciting or accepting any unfair advantage or
# benefit, in order to obtain, retain or facilitate in any way the bus iness. An unfair advantage or
# benefit may include cash, any cash equivalent (e.g. voucher), gift, credit, discount, travel,
# personal advantage, accommodation or services. We do not permit facilitation (or “grease”)
# payments to government officials or priva te business in order to secure or speed up routine
# actions.
# ===============================
# Corruption also covers the misuse of function or position as well, when someone
# makes that false appearance that s/he improperly influences a decision maker. Corruption for either to obtain or retain business, or to obtain or retain an advantage in the
# conduct of business is considered gross misconduct. Similarly accepting or allowing another
# person to accept a bribe is considered gross misconduct. Our staff’s has to account for all
# benefits received in the course of doing business and must to not give or receive bribes or
# otherwise act corruptly. 12.
# ===============================
# Gifts & Hospitality
#
# We shall avoid any actions that create a perception that favourable treatment was sought,
# received or given in exchange for personal benefits. Business courtesies or benefits include gifts, gratuities, meals, refreshments, entertainment or
# other advantages from persons or companies with whom we do or may do business. We will
# neither give nor accept such benefits that constitute, or could reasonab ly be perceived as
# constituting, unfair business inducements that would violate law, regulation or policies, or
# would cause embarrassment.
# ===============================
# Our staff may never use personal funds or resources to do
# something that cannot be done with our resources. We may accept and offer occasional gifts and hospitality that are customary and conform
# to reasonable ethical practices of the market, provided that they are not inappropriately
# excessive, not frequent and do not reflect a pattern of frequent acceptance, d oes not
# create the appearance of an attempt to influence business decisions. Only trivial gifts with
# low value can be accepted. All other gifts must be politely refused or, if received through
# post, returned to the donor.
# ===============================
# If return is not possible it shall be offered for charity or community    14. 13. purposes. It is the responsibility of the person offering, providing, receiving or accepting the
# gift to decide whether the gift is appropriate. Security, Protection & Proper Use of Company Assets
#
# We are responsible for the security, protection and for the economic use of company
# resources. Our resources, including time, material, equipment and information are provided
# for legitimate business use only. Occasional personal use is permissible as long as it is lawful,
# does not affect job performance or disrupts workplace morale.
# ===============================
# All staff is obliged to follow appropriate security measures and they should treat company
# property, whether material or intangible, with respect and shouldn’t misuse company assets
# or use it carelessly. 16. Confidentiality, Information Security, & Intellectual
# Property
#
# We are committed to business information confidentiality, integrity and accessibility, we
# implement proper technical security measures and it is our staff’s obligation to uphold this. Proprietary information includes all non -public information that might b e harmful to the
# company or its customers, business partners if disclosed to unauthorised parties.
# ===============================
# All staff must
# handle any such information as secret. It also covers that, no one is entitled to trade with
# securities while in possession of non -public info rmation or deliver non -public information to
# others that could have an impact on the securities. Every rule ensuring information security
# must be followed all the time. We respect the property rights of others. We will not acquire or seek to acquire trade secrets
# or other proprietary or confidential information by improper means. We will not engage in
# unauthorized use, copying, distribution or alteration of software or ot her protected
# intellectual property. 17.
# ===============================
# Bookkeeping, True Reporting & Financial Integrity
#
# Our books, records, accounts and financial statements must be maintained in appropriate
# detail, must truly and properly reflect our transactions. We condemn all forms of money
# laundering, so we are committed to do business with partners involved in legitim ate business
# activities with funds derived from legitimate sources. We commit ourselves to fair taxation and to avoid all tax evasion practices, including such as
# failing to issue receipt or accounting fake expense invoices.
# ===============================
# All staff must follow accounting procedures, ensure that business transactions are recorded
# and documented appropriately and make certain that all disclosures made in financial
# reports are full, honest, accurate, timely and understandable. All staff must n ot improperly
# influence, manipulate or mislead any audit. 18. Anti-fraud
#
# Fraud – the act or intent to cheat, steal, deceive or lie – is both unethical and, in most cases,
# criminal. Fraud in every form, (including e.g.
# ===============================
# submitting false expense reports; forging or
# altering financial documents or certifications; misappropriation o f assets or misusing
# company property; making any untrue financial or non -financial entry on records or
# statements) is prohibited. 19. Conflict of Interests
#
# Our decisions shall be based on objective and fair assessments avoiding the possibility of any
# improper influence. A "conflict of interest" exists when an employee's personal interest (that
# can be linked to e.g. friends, family, or customer, competitor, su pplier, contractor entity, as
# well) interferes or potentially interferes with the best interests of EnFuse.
# ===============================
# Determining whether
# a conflict of interest exists is not always easy to do, thus anyone with a conflict of interest
# question should seek advice from  management. Conflicts of interest could arise:
# ▪ Being employed (you or a close family member) by, or being in economic relation with
# an actual or potential customer, competitor, supplier or contractor
# ▪ Hiring or supervising family members or closely related persons
# ▪ Serving as a board member for another company or organization     20. ▪ Owning or having a substantial interest in a customer, competitor, supplier or contractor
# 19.
# ===============================
# ▪ Having a personal interest, financial interest or potential personal gain in any company
# transaction
# If co -workers become involved in personal relations with each other, the onus is on the senior
# employee concerned to bring this to the attention of his or her manager to confirm that
# there is no conflict of interest, nor will a conflict of interest arise. 18. Privacy, Personal Data Protection
#
# We respect people’s privacy and we acknowledge customers, employees and other natural
# persons’ need to feel confident that their personal data is processed appropriately and for a
# legitimate business purpose.
# ===============================
# We are committed to comply with all personal data protection
# laws. We only acquire and keep personal information that is necessary and we give proper
# information on these activities to data owners. We implement proper security measures to
# assure confidentiality, integrity and availability of personal information. Our staff must observe the legal requirements, apply compliant practices and follow related
# procedures to ensure legality of personal data handling and processing activities.
# ===============================
# Our staff must observe the legal requirements, apply compliant practices and follow related
# procedures to ensure legality of personal data handling and processing activities.We implement proper security measures to
# assure confidentiality, integrity and availability of personal information.
# ===============================

# %%
import re

def split_text_into_chunks(text, chunk_size=1200, chunk_overlap=120):
    """Split text into smaller chunks with overlap while preserving sentence boundaries."""

    # Regular expression to match sentence boundaries (., ?, !, etc.)
    sentence_endings = re.compile(r'([.!?])\s+')

    # Split the text into sentences while keeping the punctuation marks
    sentences = sentence_endings.split(text)
    sentences = [sentences[i] + sentences[i+1] for i in range(0, len(sentences)-1, 2)]

    # Ensure the last sentence is added if text ends without punctuation
    if len(sentences) * 2 != len(sentence_endings.findall(text)):
        sentences.append(sentences[-1] + sentences[-2])

    chunks = []
    current_chunk = []
    current_length = 0

    for sentence in sentences:
        sentence_length = len(sentence)

        # If adding the sentence exceeds chunk size, finalize the current chunk
        if current_length + sentence_length > chunk_size:
            chunks.append(" ".join(current_chunk).strip())

            # Implement overlap: Keep last 'chunk_overlap' characters for the next chunk
            overlap_text = current_chunk[-1][-chunk_overlap:] if current_chunk else ""
            current_chunk = [overlap_text] if overlap_text else []
            current_length = len(overlap_text)

        # Add the new sentence
        current_chunk.append(sentence)
        current_length += sentence_length

    # Add the last chunk if it has content
    if current_chunk:
        chunks.append(" ".join(current_chunk).strip())

    return chunks

# %%
final = split_text_into_chunks(text)
for i in final:
    print(i)
    print("===============================")
# Out:
# Code of Conduct
#
# Policy Document
#
# 1. Message from the Co -Founder & Director
#
# Our commitment to ethical behavior and the solid ethical foundations are one of the most
# essential components of EnFuse Solutions Ltd. operation. We are committed to doing
# business the right way, based on a culture of ethics and compliance. In the long term, we can successfully face the challenges of a competitive market
# environment by accepting the imperatives of moral responsibility, both as individuals and as a
# company. In performing the job duties, the employees should always act lawfully , ethically
# and in the best interests of the EnFuse Solutions Ltd. Thank you for upholding our values and helping us do things right. It does not only mean that
# we provide well made, fairly priced and of exceptional quality products and services, but it
# also means that ethics and integrity is always born in mind. We sourc e material only from
# suppliers who have impeccable human rights and compliance records, and we ensure that
# our supply chain is of high integrity, and we monitor our entire operation for compliance with
# our Code.
# ===============================
# e ensure that
# our supply chain is of high integrity, and we monitor our entire operation for compliance with
# our Code. Co-Founder & Director :
#  Kamran Shaikh and Imran Ansari are the Co -Founder and Director. 2. Introduction
#
# This Code of Ethics and Business Conduct  of EnFuse Solutions Ltd. (EnFuse, The Company) serves
# as our ethical commitment and as a guide to proper business conduct for all of our
# stakeholders. We, at EnFuse Solutions Ltd. are committed to doing business legally, ethically
# and in a transparent mann er. This document applies to all staff who work for EnFuse (including officers, directors, managers,
# team leaders, employees, temporary, agency, interim, sub -contractor or consultant staff), and
# also includes other organizations who do business with us. EnFuse expects its staff to be impartial and honest in all affairs relating to their job. All staff
# bear a responsibility in general, to be of good faith and do nothing to destroy the trust
# necessary for employment. The success of our business is based on the trust we earn from our employees, customers, and
# shareholders.
# ===============================
# The success of our business is based on the trust we earn from our employees, customers, and
# shareholders. We gain credibility by adhering to our commitment to fairness and reaching our
# goals solely through ethical conduct. All staff are expected to adhere  to this Code in their
# professional, as well as personal conduct, treat everyone with respect, honesty, and fairness. EnFuse is open to any questions at any time and will not allow punishment or retaliation against
# anyone for reporting a misconduct in good faith. Managers and leaders have higher responsibility for demonstrating, also through their actions, the
# importance of this Code. Managers and leaders are responsible for promptly addressing every
# raised ethical question or concern. Employees must cooperate in i nvestigations of potential or
# alleged misconduct. Non-compliance to this Code is considered as misconduct that could warrant disciplinary action,
# including termination of employment or other contract in deserving cases. We are committed to making efforts to apply our values and norms also throughout the entire
# value chain of our own suppliers, sub -contractors, service providers and business partners. 3.
# ===============================
# 3. Ethical Principles of EnFuse
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set of
# core values that form the foundation of our business conduct. These principles reflect who we
# are as an organization and shape our interactions with clients, co lleagues, and the broader
# community. 1. Honesty:
# – Employees should provide accurate and truthful information in all business interactions
# – Avoid deceptive practices, including misleading advertising, and be transparent in
# communications
# 2. Integrity:
# – Act ethically and uphold high moral principles in all business activities –    Avoid conflicts of
# interest and disclose any potential conflicts that may arise
# 3. Trustworthiness:
# – Build trust with clients, customers, and colleagues by consistently delivering on promises
# and commitments
# – Safeguard confidential information and respect privacy
# 4. Respect for Others:
# – Treat all individuals with dignity and respect, regardless of differences such as race,
# gender, ethnicity, or background
# – Foster an inclusive and diverse work environment that values different perspectives
# 5.
# ===============================
# nicity, or background
# – Foster an inclusive and diverse work environment that values different perspectives
# 5. Responsibility:
# – Take ownership of one's actions and decisions
# – Consider the impact of decisions on stakeholders, including employees, customers, and
# the community
# 6. Accountability:
# – Hold oneself accountable for personal and professional behavior
# – Admit mistakes, learn from them, and take corrective actions when necessary
# 7. Reliability:
# – Consistently deliver quality products and services
# – Honor commitments and deadlines, and communicate proactively if challenges arise
# 8. Obedience to the Law:
# – Conduct business in compliance with all applicable laws and regulations
# – Foster a culture of legal and ethical behavior and report any illegal activities promptly
#
#
# 9. Professional Development:
# – Encourage continuous learning and development to enhance professional competence
# – Stay informed about industry standards and best practices
# 10.
# ===============================
# development to enhance professional competence
# – Stay informed about industry standards and best practices
# 10. Environmental and Social Responsibility:
# – Promote environmentally sustainable practices
# – Contribute positively to the communities in which the business operates
# 11. Conflict Resolution:
# – Encourage open communication to resolve conflicts in a constructive and respectful
# manner
# – Seek mediation or other appropriate channels when conflicts arise
# 12. Whistleblower Protection:
# – Provide protection and support for employees who report unethical behavior or violations
# of the Code of Ethics
# – Establish clear channels for reporting, investigation, and resolution of ethical concerns
#
#
# 4. Ethical Decision Making
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set
# of core values that form the foundation of our business conduct. These principles reflect who
# we are as an organization and shape our interactions with clients, co lleagues, and the broader
# community. 1.
# ===============================
# 1. Legal Compliance:
# – Ensure that your actions are not only aligned with our values but also comply with all
# relevant laws and regulations    2. Alignment with Company Values:
# – Uphold our company values and ethical principles in every decision and action,
# contributing to a workplace culture rooted in integrity
# 3. Adherence to Code and Policies:
# – Follow our Code of Ethics and company policies diligently, providing a foundation for
# ethical behavior within the organization
# 4. Respect for Others' Rights:
# – Always consider the rights and well -being of others in your actions, fostering a workplace
# characterized by respect and empathy
# 5. Reputational Consideration:
# – Envision how your decisions would be perceived if they were to make headlines. Uphold
# our reputation by making choices that reflect positively on EnFuse
# 6. Loyalty to Stakeholders:
# – Demonstrate loyalty to your colleagues, your family, and yourself by making decisions
# that prioritize long -term well -being over short -term gains
# 7.
# ===============================
# es, your family, and yourself by making decisions
# that prioritize long -term well -being over short -term gains
# 7. The Right Thing to Do:
# – Embrace the question 'Is this the right thing to do?' as a guiding principle, ensuring that
# your actions align with your moral compass
# 8. Resistance to Misrepresentation:
# – Stand firm in your commitment to integrity. If asked to misrepresent information or
# deviate from normal procedures, resist and uphold the values that define EnFuse. 5. Compliance with Laws & Regulations
#
# Our commitment to integrity begins with complying with laws, rules and regulations. We
# understand and comply with the legal requirements and commercial practices of lawful business. We are committed to adhere to every valid and binding contractual agreement that we
#
# conclude, and we do not abuse our rights. ▪ Companies Act, 2013 (India):  We being a public company ensure compliance with the
# Companies Act. This includes aspects like corporate governance, financial reporting, and
# meeting disclosure requirements.
# ===============================
# This includes aspects like corporate governance, financial reporting, and
# meeting disclosure requirements. Our code of conduct could address ethical practices in
# these areas, such as preve nting insider trading and maintaining accurate financial records. ▪ SEBI (ICDR) Regulations, 2018:  As a company listed on the National Stock Exchange (NSE),
# EnFuse Solutions adheres to regulations set by the Securities and Exchange Board of India
# (SEBI). These regulations focus on protecting investor interests through transparent
# disclosures and fair market practices. ▪ Labor Laws:  Indian labor laws mandate fair wages, safe working conditions, and adherence
# to working hours. EnFuse Solutions' code reflects their commitment to these aspects. ▪ Data Privacy:  With our focus on data management and analytics, EnFuse Solutions has a
# robust data privacy policy aligned with Indian regulations. Our code emphasizes
# responsible data handling and user privacy protection. ▪ Intellectual Property:  The code might address respecting intellectual property rights of both
# EnFuse Solutions and their clients.
# ===============================
# l Property:  The code might address respecting intellectual property rights of both
# EnFuse Solutions and their clients. A strong code of conduct policy that aligns with relevant laws and regulations demonstrates
# EnFuse Solutions' commitment to ethical business practices. This enables building trust with
# stakeholders and investors. Our staff must follow applicable laws and regulations, including the Code of Ethics and
# Business Conduct at all times and must ensure compliant operation. Human Rights
# We are committed to respect human dignity and rights of each individual and community
# whom we interact with during the course of work. We shall not, in any way, cause or
#
# 6. contribute to the violation of human rights. Our staff shall treat everybody with dignity,
# respect and care and uphold human rights. 7. Fair Labour Practices & Working Conditions
#
# We are committed to promote equality in our employment practices and to fair employment
# and remuneration policy in compliance with applicable laws. We are firmly opposed to
# employing or contracting child or slave labour or any form of forced or compulsory or
# bonded labour.
# ===============================
# firmly opposed to
# employing or contracting child or slave labour or any form of forced or compulsory or
# bonded labour. We condemn all forms of illegal, unfair, unethical labour practice that
# exploits workforce, destroys social security or serves as tax evasion, including but not limited
# to undeclared and “grey” work or holding back wages. Our staff shall act with integrity and treat their colleagues and others through the work with
# full respect. 8. Discrimination & Harassment
# We provide equal opportunity in employment and we do not tolerate any discrimination or
# harassment or any type of abuse. No direct or indirect discrimination shall take place based
# on any professionally non -relevant trait or circumstance, like gender, mari tal status, age,
# national or social or ethnic origin, colour, religion and political opinion, disability, sexual
# orientation, employee representation, property, birth or other status. Any kind of
# discriminatory behaviour, harassment, bullying or victimizat ion is prohibited.
# ===============================
# Any kind of
# discriminatory behaviour, harassment, bullying or victimizat ion is prohibited. All staff are expected to follow the highest standards of conduct in all verbal and written
# communication based on mutual respect, and must refrain from any form of harassment,
# slander or any behaviour that could be taken as offensive, intimidating, humili ating,
# malicious or insulting. 9. Health, Safety & Environment
#
# We provide clean, safe and healthy work conditions and we are dedicated to maintaining a
# healthy environment. We are committed to minimise the impact on the natural environment
# of our operations. We make efforts to reduce the use of finite resources, like energy or water,
# and the harmful emissions, like waste. All staff must follow and comply with every relevant health, safety and environmental
# protection laws, regulations and rules all times. 10. Fair Competition & Business Conduct
#
# Our relationships with business partners are built upon trust and mutual benefits compliant
# with competition law. We are dedicated to ethical and fair competition, as we sell services
# based on their quality, functionality and competitive pricing.
# ===============================
# ted to ethical and fair competition, as we sell services
# based on their quality, functionality and competitive pricing. We will m ake independent
# pricing and marketing decisions and will not improperly cooperate or coordinate our
# activities with our competitors. We will not offer or solicit improper payments or gratuities, nor
# will we engage or assist in unlawful boycotts of particul ar customers. We commit to comply
# with all applicable trade controls, restrictions, sanctions and import -export embargoes. We do not allow any violence of the fairness of any tendering process in any way. We refrain
# from damaging competition and the reputation of any business partners and any behaviour
# that harms competitor’s credibility. 11. We do not hold back maliciously, unlawfully or unduly payments towards our partners, and
# we do not allow such practices in our supply chain, we fight the unethical practice of “debt
# chain”. 11. Our staff is responsible for ensuring fair business during their job and adhere to every
# competition, consumer protection and fair marketing rule.
# ===============================
# r ensuring fair business during their job and adhere to every
# competition, consumer protection and fair marketing rule. Customers and business partners
# shall be treated fairly and equally, products and services shall be displayed  in a manner that
#
#
# is fair and accurate (fair marketing and advertising), and that discloses all relevant
# information. 11. Anti-corruption
#
# We firmly condemn and do not tolerate all forms of corruption. It is prohibited directly or
# indirectly offering, promising, giving, asking, soliciting or accepting any unfair advantage or
# benefit, in order to obtain, retain or facilitate in any way the bus iness. An unfair advantage or
# benefit may include cash, any cash equivalent (e.g. voucher), gift, credit, discount, travel,
# personal advantage, accommodation or services. We do not permit facilitation (or “grease”)
# payments to government officials or priva te business in order to secure or speed up routine
# actions. Corruption also covers the misuse of function or position as well, when someone
# makes that false appearance that s/he improperly influences a decision maker.
# ===============================
# unction or position as well, when someone
# makes that false appearance that s/he improperly influences a decision maker. Corruption for either to obtain or retain business, or to obtain or retain an advantage in the
# conduct of business is considered gross misconduct. Similarly accepting or allowing another
# person to accept a bribe is considered gross misconduct. Our staff’s has to account for all
# benefits received in the course of doing business and must to not give or receive bribes or
# otherwise act corruptly. 12. Gifts & Hospitality
#
# We shall avoid any actions that create a perception that favourable treatment was sought,
# received or given in exchange for personal benefits. Business courtesies or benefits include gifts, gratuities, meals, refreshments, entertainment or
# other advantages from persons or companies with whom we do or may do business. We will
# neither give nor accept such benefits that constitute, or could reasonab ly be perceived as
# constituting, unfair business inducements that would violate law, regulation or policies, or
# would cause embarrassment. Our staff may never use personal funds or resources to do
# something that cannot be done with our resources.
# ===============================
# Our staff may never use personal funds or resources to do
# something that cannot be done with our resources. We may accept and offer occasional gifts and hospitality that are customary and conform
# to reasonable ethical practices of the market, provided that they are not inappropriately
# excessive, not frequent and do not reflect a pattern of frequent acceptance, d oes not
# create the appearance of an attempt to influence business decisions. Only trivial gifts with
# low value can be accepted. All other gifts must be politely refused or, if received through
# post, returned to the donor. If return is not possible it shall be offered for charity or community    14. 13. purposes. It is the responsibility of the person offering, providing, receiving or accepting the
# gift to decide whether the gift is appropriate. Security, Protection & Proper Use of Company Assets
#
# We are responsible for the security, protection and for the economic use of company
# resources. Our resources, including time, material, equipment and information are provided
# for legitimate business use only.
# ===============================
# Our resources, including time, material, equipment and information are provided
# for legitimate business use only. Occasional personal use is permissible as long as it is lawful,
# does not affect job performance or disrupts workplace morale. All staff is obliged to follow appropriate security measures and they should treat company
# property, whether material or intangible, with respect and shouldn’t misuse company assets
# or use it carelessly. 16. Confidentiality, Information Security, & Intellectual
# Property
#
# We are committed to business information confidentiality, integrity and accessibility, we
# implement proper technical security measures and it is our staff’s obligation to uphold this. Proprietary information includes all non -public information that might b e harmful to the
# company or its customers, business partners if disclosed to unauthorised parties. All staff must
# handle any such information as secret. It also covers that, no one is entitled to trade with
# securities while in possession of non -public info rmation or deliver non -public information to
# others that could have an impact on the securities.
# ===============================
# n of non -public info rmation or deliver non -public information to
# others that could have an impact on the securities. Every rule ensuring information security
# must be followed all the time. We respect the property rights of others. We will not acquire or seek to acquire trade secrets
# or other proprietary or confidential information by improper means. We will not engage in
# unauthorized use, copying, distribution or alteration of software or ot her protected
# intellectual property. 17. Bookkeeping, True Reporting & Financial Integrity
#
# Our books, records, accounts and financial statements must be maintained in appropriate
# detail, must truly and properly reflect our transactions. We condemn all forms of money
# laundering, so we are committed to do business with partners involved in legitim ate business
# activities with funds derived from legitimate sources. We commit ourselves to fair taxation and to avoid all tax evasion practices, including such as
# failing to issue receipt or accounting fake expense invoices.
# ===============================
# and to avoid all tax evasion practices, including such as
# failing to issue receipt or accounting fake expense invoices. All staff must follow accounting procedures, ensure that business transactions are recorded
# and documented appropriately and make certain that all disclosures made in financial
# reports are full, honest, accurate, timely and understandable. All staff must n ot improperly
# influence, manipulate or mislead any audit. 18. Anti-fraud
#
# Fraud – the act or intent to cheat, steal, deceive or lie – is both unethical and, in most cases,
# criminal. Fraud in every form, (including e.g. submitting false expense reports; forging or
# altering financial documents or certifications; misappropriation o f assets or misusing
# company property; making any untrue financial or non -financial entry on records or
# statements) is prohibited. 19. Conflict of Interests
#
# Our decisions shall be based on objective and fair assessments avoiding the possibility of any
# improper influence. A "conflict of interest" exists when an employee's personal interest (that
# can be linked to e.g.
# ===============================
# A "conflict of interest" exists when an employee's personal interest (that
# can be linked to e.g. friends, family, or customer, competitor, su pplier, contractor entity, as
# well) interferes or potentially interferes with the best interests of EnFuse. Determining whether
# a conflict of interest exists is not always easy to do, thus anyone with a conflict of interest
# question should seek advice from  management. Conflicts of interest could arise:
# ▪ Being employed (you or a close family member) by, or being in economic relation with
# an actual or potential customer, competitor, supplier or contractor
# ▪ Hiring or supervising family members or closely related persons
# ▪ Serving as a board member for another company or organization     20. ▪ Owning or having a substantial interest in a customer, competitor, supplier or contractor
# 19.
# ===============================
# ▪ Owning or having a substantial interest in a customer, competitor, supplier or contractor
# 19. ▪ Having a personal interest, financial interest or potential personal gain in any company
# transaction
# If co -workers become involved in personal relations with each other, the onus is on the senior
# employee concerned to bring this to the attention of his or her manager to confirm that
# there is no conflict of interest, nor will a conflict of interest arise. 18. Privacy, Personal Data Protection
#
# We respect people’s privacy and we acknowledge customers, employees and other natural
# persons’ need to feel confident that their personal data is processed appropriately and for a
# legitimate business purpose. We are committed to comply with all personal data protection
# laws. We only acquire and keep personal information that is necessary and we give proper
# information on these activities to data owners. We implement proper security measures to
# assure confidentiality, integrity and availability of personal information.
# ===============================
# We implement proper security measures to
# assure confidentiality, integrity and availability of personal information. Our staff must observe the legal requirements, apply compliant practices and follow related
# procedures to ensure legality of personal data handling and processing activities. Our staff must observe the legal requirements, apply compliant practices and follow related
# procedures to ensure legality of personal data handling and processing activities.We implement proper security measures to
# assure confidentiality, integrity and availability of personal information.
# ===============================

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Custom separators to prioritize sentence boundaries
separators = [". ", "? ", "! ", "\n", ", ", " ", ""]

# Define the text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1200,  # Adjust based on your needs
    chunk_overlap=120,  # To ensure continuity between chunks
    length_function=len,
    separators=separators
)

# Perform text splitting
chunks = text_splitter.split_text(text)
print(chunks)
# Print the resulting chunks
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i}:\n{chunk}\n")
# Out:
# ['Code of Conduct     \n    \nPolicy Document     \n    \n1.    Message from the Co -Founder & Director     \n    \nOur commitment to ethical behavior and the solid ethical foundations are one of the most \nessential components of EnFuse Solutions Ltd. operation. We are committed to doing \nbusiness the right way, based on a culture of ethics and compliance.     \nIn the long term, we can successfully face the challenges of a competitive market \nenvironment by accepting the imperatives of moral responsibility, both as individuals and as a \ncompany. In performing the job duties, the employees should always act lawfully , ethically \nand in the best interests of the EnFuse Solutions Ltd.      \nThank you for upholding our values and helping us do things right. It does not only mean that \nwe provide well made, fairly priced and of exceptional quality products and services, but it \nalso means that ethics and integrity is always born in mind. We sourc e material only from \nsuppliers who have impeccable human rights and compliance records, and we ensure that \nour supply chain is of high integrity, and we monitor our entire operation for compliance with \nour Code', '.    \nCo-Founder & Director : \n Kamran Shaikh and Imran Ansari are the Co -Founder and Director.   \n     \n2.     Introduction     \n    \nThis Code of Ethics and Business Conduct  of EnFuse Solutions Ltd. (EnFuse, The Company) serves \nas our ethical commitment and as a guide to proper business conduct for all of our \nstakeholders. We, at EnFuse Solutions Ltd. are committed to doing business legally, ethically \nand in a transparent mann er.       \nThis document applies to all staff who work for EnFuse (including officers, directors, managers, \nteam leaders, employees, temporary, agency, interim, sub -contractor or consultant staff), and \nalso includes other organizations who do business with us.     \nEnFuse expects its staff to be impartial and honest in all affairs relating to their job. All staff \nbear a responsibility in general, to be of good faith and do nothing to destroy the trust \nnecessary for employment.     \nThe success of our business is based on the trust we earn from our employees, customers, and \nshareholders. We gain credibility by adhering to our commitment to fairness and reaching our \ngoals solely through ethical conduct', '. We gain credibility by adhering to our commitment to fairness and reaching our \ngoals solely through ethical conduct. All staff are expected to adhere  to this Code in their \nprofessional, as well as personal conduct, treat everyone with respect, honesty, and fairness.     \nEnFuse is open to any questions at any time and will not allow punishment or retaliation against \nanyone for reporting a misconduct in good faith.     \nManagers and leaders have higher responsibility for demonstrating, also through their actions, the \nimportance of this Code. Managers and leaders are responsible for promptly addressing every \nraised ethical question or concern. Employees must cooperate in i nvestigations of potential or \nalleged misconduct.      \nNon-compliance to this Code is considered as misconduct that could warrant disciplinary action, \nincluding termination of employment or other contract in deserving cases.     \nWe are committed to making efforts to apply our values and norms also throughout the entire \nvalue chain of our own suppliers, sub -contractors, service providers and business partners.     \n     \n      \n3', '.     \n     \n      \n3.    Ethical Principles of EnFuse     \nAt EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set of \ncore values that form the foundation of our business conduct. These principles reflect who we \nare as an organization and shape our interactions with clients, co lleagues, and the broader \ncommunity.     \n1. Honesty:     \n– Employees should provide accurate and truthful information in all business interactions     \n– Avoid de ...
# Chunk 1:
# Code of Conduct
#
# Policy Document
#
# 1.    Message from the Co -Founder & Director
#
# Our commitment to ethical behavior and the solid ethical foundations are one of the most
# essential components of EnFuse Solutions Ltd. operation. We are committed to doing
# business the right way, based on a culture of ethics and compliance.
# In the long term, we can successfully face the challenges of a competitive market
# environment by accepting the imperatives of moral responsibility, both as individuals and as a
# company. In performing the job duties, the employees should always act lawfully , ethically
# and in the best interests of the EnFuse Solutions Ltd.
# Thank you for upholding our values and helping us do things right. It does not only mean that
# we provide well made, fairly priced and of exceptional quality products and services, but it
# also means that ethics and integrity is always born in mind. We sourc e material only from
# suppliers who have impeccable human rights and compliance records, and we ensure that
# our supply chain is of high integrity, and we monitor our entire operation for compliance with
# our Code
#
# Chunk 2:
# .
# Co-Founder & Director :
#  Kamran Shaikh and Imran Ansari are the Co -Founder and Director.
#
# 2.     Introduction
#
# This Code of Ethics and Business Conduct  of EnFuse Solutions Ltd. (EnFuse, The Company) serves
# as our ethical commitment and as a guide to proper business conduct for all of our
# stakeholders. We, at EnFuse Solutions Ltd. are committed to doing business legally, ethically
# and in a transparent mann er.
# This document applies to all staff who work for EnFuse (including officers, directors, managers,
# team leaders, employees, temporary, agency, interim, sub -contractor or consultant staff), and
# also includes other organizations who do business with us.
# EnFuse expects its staff to be impartial and honest in all affairs relating to their job. All staff
# bear a responsibility in general, to be of good faith and do nothing to destroy the trust
# necessary for employment.
# The success of our business is based on the trust we earn from our employees, customers, and
# shareholders. We gain credibility by adhering to our commitment to fairness and reaching our
# goals solely through ethical conduct
#
# Chunk 3:
# . We gain credibility by adhering to our commitment to fairness and reaching our
# goals solely through ethical conduct. All staff are expected to adhere  to this Code in their
# professional, as well as personal conduct, treat everyone with respect, honesty, and fairness.
# EnFuse is open to any questions at any time and will not allow punishment or retaliation against
# anyone for reporting a misconduct in good faith.
# Managers and leaders have higher responsibility for demonstrating, also through their actions, the
# importance of this Code. Managers and leaders are responsible for promptly addressing every
# raised ethical question or concern. Employees must cooperate in i nvestigations of potential or
# alleged misconduct.
# Non-compliance to this Code is considered as misconduct that could warrant disciplinary action,
# including termination of employment or other contract in deserving cases.
# We are committed to making efforts to apply our values and norms also throughout the entire
# value chain of our own suppliers, sub -contractors, service providers and business partners.
#
#
# 3
#
# Chunk 4:
# .
#
#
# 3.    Ethical Principles of EnFuse
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set of
# core values that form the foundation of our business conduct. These principles reflect who we
# are as an organization and shape our interactions with clients, co lleagues, and the broader
# community.
# 1. Honesty:
# – Employees should provide accurate and truthful information in all business interactions
# – Avoid deceptive practices, including misleading advertising, and be transparent in
# communications
# 2. Integrity:
# – Act ethically and uphold high moral principles in all business activities –    Avoid conflicts of
# interest and disclose any potential conflicts that may arise
# 3. Trustworthiness:
# – Build trust with clients, customers, and colleagues by consistently delivering on promises
# and commitments
# – Safeguard confidential information and respect privacy
# 4
#
# Chunk 5:
# . Respect for Others:
# – Treat all individuals with dignity and respect, regardless of differences such as race,
# gender, ethnicity, or background
# – Foster an inclusive and diverse work environment that values different perspectives
# 5. Responsibility:
# – Take ownership of one's actions and decisions
# – Consider the impact of decisions on stakeholders, including employees, customers, and
# the community
# 6. Accountability:
# – Hold oneself accountable for personal and professional behavior
# – Admit mistakes, learn from them, and take corrective actions when necessary
# 7. Reliability:
# – Consistently deliver quality products and services
# – Honor commitments and deadlines, and communicate proactively if challenges arise
# 8. Obedience to the Law:
# – Conduct business in compliance with all applicable laws and regulations
# – Foster a culture of legal and ethical behavior and report any illegal activities promptly
#
#
# 9. Professional Development:
# – Encourage continuous learning and development to enhance professional competence
# – Stay informed about industry standards and best practices
# 10
#
# Chunk 6:
# . Environmental and Social Responsibility:
# – Promote environmentally sustainable practices
# – Contribute positively to the communities in which the business operates
# 11. Conflict Resolution:
# – Encourage open communication to resolve conflicts in a constructive and respectful
# manner
# – Seek mediation or other appropriate channels when conflicts arise
# 12. Whistleblower Protection:
# – Provide protection and support for employees who report unethical behavior or violations
# of the Code of Ethics
# – Establish clear channels for reporting, investigation, and resolution of ethical concerns
#
#
# 4.
# Ethical Decision Making
# At EnFuse, we take pride in our commitment to the highest ethical standards, guided by a set
# of core values that form the foundation of our business conduct. These principles reflect who
# we are as an organization and shape our interactions with clients, co lleagues, and the broader
# community.
# 1. Legal Compliance:
# – Ensure that your actions are not only aligned with our values but also comply with all
# relevant laws and regulations    2
#
# Chunk 7:
# . Alignment with Company Values:
# – Uphold our company values and ethical principles in every decision and action,
# contributing to a workplace culture rooted in integrity
# 3. Adherence to Code and Policies:
# – Follow our Code of Ethics and company policies diligently, providing a foundation for
# ethical behavior within the organization
# 4. Respect for Others' Rights:
# – Always consider the rights and well -being of others in your actions, fostering a workplace
# characterized by respect and empathy
# 5. Reputational Consideration:
# – Envision how your decisions would be perceived if they were to make headlines. Uphold
# our reputation by making choices that reflect positively on EnFuse
# 6. Loyalty to Stakeholders:
# – Demonstrate loyalty to your colleagues, your family, and yourself by making decisions
# that prioritize long -term well -being over short -term gains
# 7. The Right Thing to Do:
# – Embrace the question 'Is this the right thing to do?' as a guiding principle, ensuring that
# your actions align with your moral compass
# 8. Resistance to Misrepresentation:
# – Stand firm in your commitment to integrity
#
# Chunk 8:
# . Resistance to Misrepresentation:
# – Stand firm in your commitment to integrity. If asked to misrepresent information or
# deviate from normal procedures, resist and uphold the values that define EnFuse.
# 5.    Compliance with Laws & Regulations
#
# Our commitment to integrity begins with complying with laws, rules and regulations. We
# understand and comply with the legal requirements and commercial practices of lawful business.
#
#
# We are committed to adhere to every valid and binding contractual agreement that we
#
# conclude, and we do not abuse our rights.
# ▪ Companies Act, 2013 (India):  We being a public company ensure compliance with the
# Companies Act. This includes aspects like corporate governance, financial reporting, and
# meeting disclosure requirements. Our code of conduct could address ethical practices in
# these areas, such as preve nting insider trading and maintaining accurate financial records.
# ▪ SEBI (ICDR) Regulations, 2018:  As a company listed on the National Stock Exchange (NSE),
# EnFuse Solutions adheres to regulations set by the Securities and Exchange Board of India
# (SEBI)
#
# Chunk 9:
# . These regulations focus on protecting investor interests through transparent
# disclosures and fair market practices.
# ▪ Labor Laws:  Indian labor laws mandate fair wages, safe working conditions, and adherence
# to working hours. EnFuse Solutions' code reflects their commitment to these aspects.
# ▪ Data Privacy:  With our focus on data management and analytics, EnFuse Solutions has a
# robust data privacy policy aligned with Indian regulations. Our code emphasizes
# responsible data handling and user privacy protection.
# ▪ Intellectual Property:  The code might address respecting intellectual property rights of both
# EnFuse Solutions and their clients.
# A strong code of conduct policy that aligns with relevant laws and regulations demonstrates
# EnFuse Solutions' commitment to ethical business practices. This enables building trust with
# stakeholders and investors.
# Our staff must follow applicable laws and regulations, including the Code of Ethics and
# Business Conduct at all times and must ensure compliant operation
#
# Chunk 10:
# .
# Human Rights
# We are committed to respect human dignity and rights of each individual and community
# whom we interact with during the course of work. We shall not, in any way, cause or
#
# 6.
# contribute to the violation of human rights. Our staff shall treat everybody with dignity,
# respect and care and uphold human rights.           7.
# Fair Labour Practices & Working Conditions
#
# We are committed to promote equality in our employment practices and to fair employment
# and remuneration policy in compliance with applicable laws. We are firmly opposed to
# employing or contracting child or slave labour or any form of forced or compulsory or
# bonded labour. We condemn all forms of illegal, unfair, unethical labour practice that
# exploits workforce, destroys social security or serves as tax evasion, including but not limited
# to undeclared and “grey” work or holding back wages.
# Our staff shall act with integrity and treat their colleagues and others through the work with
# full respect.            8
#
# Chunk 11:
# .            8.
# Discrimination & Harassment
# We provide equal opportunity in employment and we do not tolerate any discrimination or
# harassment or any type of abuse. No direct or indirect discrimination shall take place based
# on any professionally non -relevant trait or circumstance, like gender, mari tal status, age,
# national or social or ethnic origin, colour, religion and political opinion, disability, sexual
# orientation, employee representation, property, birth or other status. Any kind of
# discriminatory behaviour, harassment, bullying or victimizat ion is prohibited.
# All staff are expected to follow the highest standards of conduct in all verbal and written
# communication based on mutual respect, and must refrain from any form of harassment,
# slander or any behaviour that could be taken as offensive, intimidating, humili ating,
# malicious or insulting.              9.
# Health, Safety & Environment
#
# We provide clean, safe and healthy work conditions and we are dedicated to maintaining a
# healthy environment. We are committed to minimise the impact on the natural environment
# of our operations
#
# Chunk 12:
# . We are committed to minimise the impact on the natural environment
# of our operations. We make efforts to reduce the use of finite resources, like energy or water,
# and the harmful emissions, like waste.
# All staff must follow and comply with every relevant health, safety and environmental
# protection laws, regulations and rules all times.           10.
#
# Fair Competition & Business Conduct
#
# Our relationships with business partners are built upon trust and mutual benefits compliant
# with competition law. We are dedicated to ethical and fair competition, as we sell services
# based on their quality, functionality and competitive pricing. We will m ake independent
# pricing and marketing decisions and will not improperly cooperate or coordinate our
# activities with our competitors. We will not offer or solicit improper payments or gratuities, nor
# will we engage or assist in unlawful boycotts of particul ar customers. We commit to comply
# with all applicable trade controls, restrictions, sanctions and import -export embargoes.
# We do not allow any violence of the fairness of any tendering process in any way
#
# Chunk 13:
# .
# We do not allow any violence of the fairness of any tendering process in any way. We refrain
# from damaging competition and the reputation of any business partners and any behaviour
# that harms competitor’s credibility.      11.
# We do not hold back maliciously, unlawfully or unduly payments towards our partners, and
# we do not allow such practices in our supply chain, we fight the unethical practice of “debt
# chain”.
# 11.
# Our staff is responsible for ensuring fair business during their job and adhere to every
# competition, consumer protection and fair marketing rule. Customers and business partners
# shall be treated fairly and equally, products and services shall be displayed  in a manner that
#
#
# is fair and accurate (fair marketing and advertising), and that discloses all relevant
# information.
# 11.
# Anti-corruption
#
# We firmly condemn and do not tolerate all forms of corruption. It is prohibited directly or
# indirectly offering, promising, giving, asking, soliciting or accepting any unfair advantage or
# benefit, in order to obtain, retain or facilitate in any way the bus iness
#
# Chunk 14:
# . An unfair advantage or
# benefit may include cash, any cash equivalent (e.g. voucher), gift, credit, discount, travel,
# personal advantage, accommodation or services. We do not permit facilitation (or “grease”)
# payments to government officials or priva te business in order to secure or speed up routine
# actions. Corruption also covers the misuse of function or position as well, when someone
# makes that false appearance that s/he improperly influences a decision maker.
# Corruption for either to obtain or retain business, or to obtain or retain an advantage in the
# conduct of business is considered gross misconduct. Similarly accepting or allowing another
# person to accept a bribe is considered gross misconduct. Our staff’s has to account for all
# benefits received in the course of doing business and must to not give or receive bribes or
# otherwise act corruptly.              12.
# Gifts & Hospitality
#
# We shall avoid any actions that create a perception that favourable treatment was sought,
# received or given in exchange for personal benefits
#
# Chunk 15:
# .
# Business courtesies or benefits include gifts, gratuities, meals, refreshments, entertainment or
# other advantages from persons or companies with whom we do or may do business. We will
# neither give nor accept such benefits that constitute, or could reasonab ly be perceived as
# constituting, unfair business inducements that would violate law, regulation or policies, or
# would cause embarrassment. Our staff may never use personal funds or resources to do
# something that cannot be done with our resources.
# We may accept and offer occasional gifts and hospitality that are customary and conform
# to reasonable ethical practices of the market, provided that they are not inappropriately
# excessive, not frequent and do not reflect a pattern of frequent acceptance, d oes not
# create the appearance of an attempt to influence business decisions. Only trivial gifts with
# low value can be accepted. All other gifts must be politely refused or, if received through
# post, returned to the donor. If return is not possible it shall be offered for charity or community    14.
# 13.
# purposes
#
# Chunk 16:
# . If return is not possible it shall be offered for charity or community    14.
# 13.
# purposes. It is the responsibility of the person offering, providing, receiving or accepting the
# gift to decide whether the gift is appropriate.
# Security, Protection & Proper Use of Company Assets
#
# We are responsible for the security, protection and for the economic use of company
# resources. Our resources, including time, material, equipment and information are provided
# for legitimate business use only. Occasional personal use is permissible as long as it is lawful,
# does not affect job performance or disrupts workplace morale.
# All staff is obliged to follow appropriate security measures and they should treat company
# property, whether material or intangible, with respect and shouldn’t misuse company assets
# or use it carelessly.           16.
# Confidentiality, Information Security, & Intellectual
# Property
#
# We are committed to business information confidentiality, integrity and accessibility, we
# implement proper technical security measures and it is our staff’s obligation to uphold this
#
# Chunk 17:
# .
# Proprietary information includes all non -public information that might b e harmful to the
# company or its customers, business partners if disclosed to unauthorised parties. All staff must
# handle any such information as secret. It also covers that, no one is entitled to trade with
# securities while in possession of non -public info rmation or deliver non -public information to
# others that could have an impact on the securities. Every rule ensuring information security
# must be followed all the time.
# We respect the property rights of others. We will not acquire or seek to acquire trade secrets
# or other proprietary or confidential information by improper means. We will not engage in
# unauthorized use, copying, distribution or alteration of software or ot her protected
# intellectual property.             17.
# Bookkeeping, True Reporting & Financial Integrity
#
# Our books, records, accounts and financial statements must be maintained in appropriate
# detail, must truly and properly reflect our transactions
#
# Chunk 18:
# . We condemn all forms of money
# laundering, so we are committed to do business with partners involved in legitim ate business
# activities with funds derived from legitimate sources.
# We commit ourselves to fair taxation and to avoid all tax evasion practices, including such as
# failing to issue receipt or accounting fake expense invoices.
# All staff must follow accounting procedures, ensure that business transactions are recorded
# and documented appropriately and make certain that all disclosures made in financial
# reports are full, honest, accurate, timely and understandable. All staff must n ot improperly
# influence, manipulate or mislead any audit.           18.
# Anti-fraud
#
# Fraud – the act or intent to cheat, steal, deceive or lie – is both unethical and, in most cases,
# criminal. Fraud in every form, (including e.g. submitting false expense reports; forging or
# altering financial documents or certifications; misappropriation o f assets or misusing
# company property; making any untrue financial or non -financial entry on records or
# statements) is prohibited.               19
#
# Chunk 19:
# .               19.
# Conflict of Interests
#
# Our decisions shall be based on objective and fair assessments avoiding the possibility of any
# improper influence. A "conflict of interest" exists when an employee's personal interest (that
# can be linked to e.g. friends, family, or customer, competitor, su pplier, contractor entity, as
# well) interferes or potentially interferes with the best interests of EnFuse. Determining whether
# a conflict of interest exists is not always easy to do, thus anyone with a conflict of interest
# question should seek advice from  management.
# Conflicts of interest could arise:
# ▪ Being employed (you or a close family member) by, or being in economic relation with
# an actual or potential customer, competitor, supplier or contractor
# ▪ Hiring or supervising family members or closely related persons
# ▪ Serving as a board member for another company or organization     20.
# ▪ Owning or having a substantial interest in a customer, competitor, supplier or contractor
# 19
#
# Chunk 20:
# .
# ▪ Owning or having a substantial interest in a customer, competitor, supplier or contractor
# 19.
# ▪ Having a personal interest, financial interest or potential personal gain in any company
# transaction
# If co -workers become involved in personal relations with each other, the onus is on the senior
# employee concerned to bring this to the attention of his or her manager to confirm that
# there is no conflict of interest, nor will a conflict of interest arise.
#
#
# 18. Privacy, Personal Data Protection
#
# We respect people’s privacy and we acknowledge customers, employees and other natural
# persons’ need to feel confident that their personal data is processed appropriately and for a
# legitimate business purpose. We are committed to comply with all personal data protection
# laws. We only acquire and keep personal information that is necessary and we give proper
# information on these activities to data owners. We implement proper security measures to
# assure confidentiality, integrity and availability of personal information
#
# Chunk 21:
# . We implement proper security measures to
# assure confidentiality, integrity and availability of personal information.
# Our staff must observe the legal requirements, apply compliant practices and follow related
# procedures to ensure legality of personal data handling and processing activities.
